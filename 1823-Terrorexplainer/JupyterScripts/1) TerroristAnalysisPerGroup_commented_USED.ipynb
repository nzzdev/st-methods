# %%
import pandas as pd

# %% [markdown]
# We load the database (clean just stands for csv rather than xls) and then filter the database. We only include all attacks that
#
# ### a) meet the three key criterias that define terrorism:
#
#  Criterion 1: The act must be aimed at attaining a political, economic, religious, or social goal.
#  Criterion 2: There must be evidence of an intention to coerce, intimidate, or convey some other message to a larger audience (or audiences) than the immediate victims.
#  Criterion 3: The action must be outside the context of legitimate warfare activities.
#
# ### b) have at least one person killed
# ### c) there is no doubt that it was terror
# ### d) and the attackers are not unknown

# %%
GDT=pd.read_csv("../RawData/GDT_clean_database_2.csv")
print(len(GDT))
GDTclean=GDT[(GDT["crit1"]&GDT["crit2"]&GDT["crit3"]==1)]
GDTclean=GDTclean[GDTclean["nkill"]!=0]
GDTclean=GDTclean[GDTclean["doubtterr"]!=1]
GDTclean=GDTclean[GDTclean["gname"]!="Unknown"]

GDTclean["incidentno"]=1
GDT_reduced=GDTclean
print(len(GDTclean))
GDTclean
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 181691
# 41370
#              eventid  iyear  imonth  iday            approxdate  extended  \
# 0       197000000001   1970       7     2                   NaN         0
# 15      197001100001   1970       1    10                   NaN         0
# 59      197002100001   1970       2    10                   NaN         0
# 62      197002130002   1970       2    13                   NaN         0
# 80      197002210002   1970       2    21                   NaN         0
# 111     197003050003   1970       3     5                   NaN         0
# 119     197003090006   1970       3     9                   NaN         0
# 161     197003310001   1970       3    31                   NaN         1
# 171     197004030001   1970       4     3                   NaN         0
# 223     197004240002   1970       4    24                   NaN         0
# 253     197005040001   1970       5     4                   NaN         0
# 274     197005090003   1970       5     9                   NaN         0
# 277     197005120001   1970       5    12                   NaN         0
# 291     197005150004   1970       5    15                   NaN         0
# 299     197005220002   1970       5    22                   NaN         0
# 307     197005280001   1970       5    28                   NaN         0
# 311     197005290001   1970       5    29                   NaN         1
# 316     197006010001   1970       6     1                   NaN         0
# 324     197006060002   1970       6     6                   NaN         0
# 325     197006060003   1970       6     6                   NaN         0
# 329     197006070002   1970       6     7                   NaN         1
# 334     197006090002   1970       6     9                   NaN         0
# 335     197006090003   1970       6     9                   NaN         0
# 341     197006110001   1970       6    11                   NaN         1
# 357     197006190003   1970       6    19                   NaN         0
# 358     197006190004   1970       6    19                   NaN         0
# 364     197006260001   1970       6    26                   NaN         0
# 365     197006270001   1970       6    27                   NaN         0
# 366     197006270002   1970       6    27                   NaN         0
# 367     197006270003   1970       6    27                   NaN         0
# ...              ...    ...     ...   ...                   ...       ...
# 181580  201712270026   2017      12    27                   NaN         0
# 181581  201712270027   2017      12    27  December 24-30, 2017         1
# 181585  201712270032   2017      12    27                   NaN         0
# 181588  201712280001   2017      12    28                   NaN         0
# 181592  201712280005   2017      12    28                   NaN         0
# 181595  201712280008   2017      12    28                   NaN         0
# 181600  201712280016   2017      12    28                   NaN         0
# 181602  201712280019   2017      12    28                   NaN         1
# 181604  201712280021   2017      12    29                   NaN         0
# 181605  201712280022   2017      12    28                   NaN         0
# 181616  201712280036   2017      12    28                   NaN         1
# 181619  201712280039   2017      12    28   2017-12-28 00:00:00         0
# 181623  201712290001   2017      12    29                   NaN         0
# 181624  201712290002   2017      12    29                   NaN         0
# 181625  201712290003   2017      12    29                   NaN         0
# 181630  201712290008   2017      12    28                   NaN         1
# 181636  201712290017   2017      12    29                   NaN         1
# 181639  201712290024   2017      12    29                   NaN         0
# 181653  201712300011   2017      12    31                   NaN         0
# 181654  201712300012   2017      12    30                   NaN         0
# 181656  201712300014   2017      12    30                   NaN         1
# 181666  201712300025   2017      12    30                   NaN         0
# 181670  201712310003   2017      12    31   2017-12-31 00:00:00         0
# 181671  201712310004   2017      12    31                   NaN         0
# 181672  201712310005   2017      12    31                   NaN         0
# 181673  201712310006   2017      12    31                   NaN         0
# 181675  201712310008   2017      12    31                   NaN         0
# 181676  201712310009   2017      12    31                   NaN         0
# 181681  201712310016   2017      12    31                   NaN         0
# 181683  201712310018   2017      12    31                   NaN         0
#
#        resolution  country                       country_txt  region  \
# 0             NaN       58                Dominican Republic       2
# 15            NaN      499                East Germany (GDR)       9
# 59            NaN      362                West Germany (FRG)       8
# 62            NaN      362                West Germany (FRG)       8
# 80            NaN      199                       Switzerland       8
# 111           NaN      217                     United States       1
# 119           NaN      217                     United States       1
# 161      4/5/1970       83                         Guatemala       2
# 171           NaN       96                           Ireland       8
# 223           NaN      217                     United States       1
# 253           NaN      158                          Paraguay       3
# 274           NaN      217                     United States       1
# 277           NaN      199                       Switzerland       8
# 291           NaN      217                     United States       1
# 299           NaN      217                     United States       1
# 307           NaN      217                     United States       1
# 311     7/17/1970       11                         Argentina       3
# 316           NaN       11                         Argentina       3
# 324           NaN      362                West Germany (FRG)       8
# 325           NaN      362                West Germany (FRG)       8
# 329      6/8/1970      102                            Jordan      10
# 334           NaN       94                              Iran      10
# 335           NaN      217                     United States       1
# 341     6/16/1970       30                            Brazil       3
# 357           NaN      217                     United States       1
# 358           NaN      217                     United States       1
# 364           NaN      603                    United Kingdom       8
# 365           NaN      603                    United Kingdom       8
# 366           NaN      603                    United Kingdom       8
# 367           NaN      603                    United Kingdom       8
# ...           ...      ...                               ...     ...
# 181580        NaN        4                       Afghanistan       6
# 181581        NaN      228                             Yemen      10
# 181585        NaN      229  Democratic Republic of the Congo      11
# 181588        NaN        4                       Afghanistan       6
# 181592        NaN       60                             Egypt      10
# 181595        NaN       95                              Iraq      10
# 181600        NaN        4                       Afghanistan       6
# 181602        NaN      160                       Philippines       5
# 181604        NaN       37                          Cameroon      11
# 181605        NaN      147                           Nigeria      11
# 181616        NaN      228                             Yemen      10
# 181619        NaN        4                       Afghanistan       6
# 181623        NaN       95                              Iraq      10
# 181624        NaN       60                             Egypt      10
# 181625        NaN       60                             Egypt      10
# 181630        NaN      160                       Philippines       5
# 181636        NaN        4                       Afghanistan       6
# 181639        NaN       95                              Iraq      10
# 181653        NaN       37                          Cameroon      11
# 181654        NaN      147                           Nigeria      11
# 181656        NaN      147                           Nigeria      11
# 181666        NaN      147                           Nigeria      11
# 181670        NaN       95                              Iraq      10
# 181671        NaN       95                              Iraq      10
# 181672        NaN       92                             India       6
# 181673        NaN        4                       Afghanistan       6
# 181675        NaN      182                           Somalia      11
# 181676        NaN        4                       Afghanistan       6
# 181681        NaN      160                       Philippines       5
# 181683        NaN        4                       Afghanistan       6
#
#            ...                                                 scite1  \
# 0          ...                                                    NaN
# 15         ...                                                    NaN
# 59         ...                                                    NaN
# 62         ...                                                    NaN
# 80         ...                                                    NaN
# 111        ...      Committee on the Judiciary  United States Sena...
# 119        ...      Committee on Government Operations United Stat...
# 161        ...                                                    NaN
# 171        ...                                                    NaN
# 223        ...      George J. Hiltner, "City Panther is Convicted ...
# 253        ...                                                    NaN
# 274        ...      Committee on Government Operations United Stat...
# 277        ...                                                    NaN
# 291        ...      Committee on Government Operations United Stat...
# 299        ...      Committee on Government Operations United Stat...
# 307        ...                                                    NaN
# 311        ...                                                    NaN
# 316        ...                                                    NaN
# 324        ...                                                    NaN
# 325        ...                                                    NaN
# 329        ...                                                    NaN
# 334        ...                                                    NaN
# 335        ...                                                    NaN
# 341        ...                                                    NaN
# 357        ...      Committee on Government Operations United Stat...
# 358        ...      Jim Herron Zamora, "1967-71: a Bloody Period F...
# 364        ...                                                    NaN
# 365        ...                                                    NaN
# 366        ...                                                    NaN
# 367        ...                                                    NaN
# ...        ...                                                    ...
# 181580     ...      "Senior Pakistani Taliban leader blown by own ...
# 181581     ...      "Yemen: Report Says Huthis Force GPC Members T...
# 181585     ...      "North Kivu: Five civilians killed by suspecte...
# 181588     ...      "Kabul bombing: Death toll rises to 50," Anado...
# 181592     ...      "Militants kill two in bank attack in Egypt's ...
# 181595     ...      "Tribal figure killed in Islamic State attack ...
# 181600     ...      "Taliban kill 4 border police in Nangarhar amb...
# 181602     ...      "Cop slain, 5 colleagues wounded in BIFF attac...
# 181604     ...      "Xinhua: 1st Ld Writethru: Three Killed In Sus...
# 181605     ...      "Four die in Borno suicide attack," The Nation...
# 181616     ...      "Yemen: Report Says Huthis Force GPC Members T...
# 181619     ...      "Program Summary: Ghazni Ghaznawian Television...
# 181623     ...      "Iraq: Security Roundup 1900 GMT 29 December 2...
# 181624     ...      "Egypt: 10 killed in Cairo church attack by Da...
# 181625     ...      "Nine people killed in attacks on church, stor...
# 181630     ...      "NPA abducts police officer in Cotabato," Mani...
# 181636     ...      "Afghanistan- ED: Deash's threat more serious ...
# 181639     ...      "ISIL launches counteroffensive in Iraq," Azer...
# 181653     ...      "Female Suicide Bomber Kills One, Wounds 28 In...
# 181654     ...      "Nigeria Scores Killed in Boko Haram Attacks i...
# 181656     ...      "Boko Haram says it carried out Christmas atta...
# 181666     ...      "Nigeria Scores Killed in Boko Haram Attacks i...
# 181670     ...      "Iraq: Security Roundup 1900 GMT 31 December 2...
# 181671     ...      "Islamic State attack leaves thirteen civilian...
# 181672     ...      "Three soldiers killed in Indian-administered ...
# 181673     ...      "Death toll from funeral blast in eastern Afgh...
# 181675     ...      "Somalia: Al-Shabab says 5 AU soldiers dead in...
# 181676     ...      "Commander among 5 ALP members killed in Logar...
# 181681     ...      "3 dead, scores injured in Mindanao blasts," M...
# 181683     ...      "Six Members Of One Family Shot Dead In Faryab...
#
#                                                    scite2  \
# 0                                                     NaN
# 15                                                    NaN
# 59                                                    NaN
# 62                                                    NaN
# 80                                                    NaN
# 111     William Sater, "Puerto Rican Terrorists: A Pos...
# 119     Homer Bigart, "Maryland Hunts Woman In Blast,"...
# 161                                                   NaN
# 171                                                   NaN
# 223     Laurie Willis, "Judge Affirms 1972 Life Term,"...
# 253                                                   NaN
# 274     David Colvin, "Black Politics After the Civil ...
# 277                                                   NaN
# 291     "Public Service Strikes Hit San Diego," Washin...
# 299     Shannon Prather, "Court Upholds Verdict in Cop...
# 307                                                   NaN
# 311                                                   NaN
# 316                                                   NaN
# 324                                                   NaN
# 325                                                   NaN
# 329                                                   NaN
# 334                                                   NaN
# 335                                                   NaN
# 341                                                   NaN
# 357     Jody P. Weiss, State of Illinois, Prisoner Rev...
# 358     "Chicago, Coast Policemen Shot,"  Baltimore Su...
# 364                                                   NaN
# 365                                                   NaN
# 366                                                   NaN
# 367                                                   NaN
# ...                                                   ...
# 181580                                                NaN
# 181581                                                NaN
# 181585                                                NaN
# 181588  "Dozens dead, wounded in 3 blasts in Afghan ca...
# 181592  "Province of Sinai claims killings of Bir al-A...
# 181595                                                NaN
# 181600  "Highlights: Pakistan Pashto Press 29 December...
# 181602  "BIFF kills 2 kidnapped farmers, burns village...
# 181604  "SOCAFRICA: Native Prospector West Africa VEO ...
# 181605  "Suicide bomber kills six in Nigerian market,"...
# 181616                                                NaN
# 181619                                                NaN
# 181623  "1,262 Killed in Iraq During December," Antiwa...
# 181624  "Gunmen attack church near Cairo, killing nine...
# 181625  "Egypt: 10 killed in Cairo church attack by Da...
# 181630  "Police official taken by armed men in North C...
# 181636  "ISIS Abducted 12 Chaplains in Northern Jawzja...
# 181639                                                NaN
# 181653  "Female suicide bomber kills one, injures 28,"...
# 181654  "SOCAFRICA: Native Prospector West Africa VEO ...
# 181656  "Toll in Boko Haram attack on loggers rises to...
# 181666                                                NaN
# 181670  "Terrorism: Roundup of Official ISIS Messages ...
# 181671  "3 people killed in IS attack in central Iraq,...
# 181672  "Fidayeen used armour-piercing bullets in Leth...
# 181673  "The Latest: Toll from Afghan funeral bombing ...
# 181675  "Somalia: Fifteen Police Officers Complete Tra...
# 181676  "Media Highlights on Afghanistan 1 January 201...
# 181681  "Cop, 2 others killed in bomb blasts in Mindan...
# 181683  "Highlights: Pakistan Pashto Press 02 January ...
#
#                                                    scite3  \
# 0                                                     NaN
# 15                                                    NaN
# 59                                                    NaN
# 62                                                    NaN
# 80                                                    NaN
# 111     "Toward People's War for Independence and Soci...
# 119     Peter A. Jay, "Bomb Threats in Area," Washingt...
# 161                                                   NaN
# 171                                                   NaN
# 223     George J. Hiltner, "Panther Gets Life, 15 Year...
# 253                                                   NaN
# 274     "Sacramento Policeman Shot," New York Times, M...
# 277                                                   NaN
# 291                                                   NaN
# 299     "St. Paul Police Officer James Sackett, 27, Is...
# 307                                                   NaN
# 311                                                   NaN
# 316                                                   NaN
# 324                                                   NaN
# 325                                                   NaN
# 329                                                   NaN
# 334                                                   NaN
# 335                                                   NaN
# 341                                                   NaN
# 357     "Races: Ambushes in Chicago," Time Magazine, A...
# 358     "Young Policeman Slain In Berkeley," New York ...
# 364                                                   NaN
# 365                                                   NaN
# 366                                                   NaN
# 367                                                   NaN
# ...                                                   ...
# 181580                                                NaN
# 181581                                                NaN
# 181585                                                NaN
# 181588  "Over 41 killed in Kabul suicide attack: local...
# 181592  "Bomb kills 6, including army colonel, in Egyp...
# 181595                                                NaN
# 181600                                                NaN
# 181602  "Philippines: Highlights of Terrorist, Counter...
# 181604                                                NaN
# 181605  "SOCAFRICA: Native Prospector West Africa VEO ...
# 181616                                                NaN
# 181619                                                NaN
# 181623                                                NaN
# 181624  "Singapore: Gunman kills 9 in Egypt church att...
# 181625  "ISIS claim responsibility for 'jihadist' gunm...
# 181630  "Philippines: Suspected communist rebels abduc...
# 181636                                                NaN
# 181639                                                NaN
# 181653  "Xinhua: 1st LD: Two Killed In Suspected Boko ...
# 181654                                                NaN
# 181656  "Boko Haram kills four loggers in Nigeria," Th...
# 181666                                                NaN
# 181670                                                NaN
# 181671  "Daesh gunmen kill 3 in northern Iraq: Police,...
# 181672  "Kashmir gunbattle ends after 16 hrs, body of ...
# 181673  "Bombing Kills At Least 17 At Funeral In Easte...
# 181675  "Two die in Mogadishu bomb attack," Xinhua Gen...
# 181676                                                NaN
# 181681  "Cop killed, 7 injured in Maguindanao IED blas...
# 181683                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO  INT_MISC INT_ANY  \
# 0                           PGIS        0         0         0       0
# 15                          PGIS        0         1         1       1
# 59                          PGIS        0         0         1       1
# 62                          PGIS        0         1         1       1
# 80                          PGIS        1         1         0       1
# 111               Hewitt Project        0         1         0       1
# 119               Hewitt Project       -9        -9         0      -9
# 161                         PGIS        0         1         1       1
# 171                         CAIN        1         1         0       1
# 223               Hewitt Project        0         0         0       0
# 253                         PGIS        1         0         1       1
# 274               Hewitt Project       -9        -9         0      -9
# 277                         PGIS        0         1         1       1
# 291               Hewitt Project       -9        -9         0      -9
# 299               Hewitt Project       -9        -9         0      -9
# 307                         PGIS        0         0         0       0
# 311                         PGIS        0         0         0       0
# 316                         PGIS        0         0         0       0
# 324                         PGIS        1         1         1       1
# 325                         PGIS        1         0         1       1
# 329                         PGIS        0         1         1       1
# 334                         PGIS        0         0         1       1
# 335                         PGIS        0         0         0       0
# 341                         PGIS        0         1         1       1
# 357               Hewitt Project       -9        -9         0      -9
# 358               Hewitt Project       -9        -9         0      -9
# 364                         CAIN        0         0         1       1
# 365                         CAIN        0         0         1       1
# 366                         CAIN        0         0         1       1
# 367                         CAIN        0         0         1       1
# ...                          ...      ...       ...       ...     ...
# 181580  START Primary Collection        1         1         1       1
# 181581  START Primary Collection        0         0         0       0
# 181585  START Primary Collection        0         0         0       0
# 181588  START Primary Collection        0         1         0       1
# 181592  START Primary Collection        0         0         0       0
# 181595  START Primary Collection        0         1         0       1
# 181600  START Primary Collection        0         0         0       0
# 181602  START Primary Collection        0         0         0       0
# 181604  START Primary Collection        1         1         0       1
# 181605  START Primary Collection        0         0         0       0
# 181616  START Primary Collection        0         0         0       0
# 181619  START Primary Collection        0         0         0       0
# 181623  START Primary Collection        0         1         0       1
# 181624  START Primary Collection        0         0         0       0
# 181625  START Primary Collection        0         0         0       0
# 181630  START Primary Collection        0         0         0       0
# 181636  START Primary Collection        0         1         0       1
# 181639  START Primary Collection        0         1         0       1
# 181653  START Primary Collection        1         1         0       1
# 181654  START Primary Collection        0         0         0       0
# 181656  START Primary Collection        0         0         0       0
# 181666  START Primary Collection        0         0         0       0
# 181670  START Primary Collection        0         1         0       1
# 181671  START Primary Collection        0         1         0       1
# 181672  START Primary Collection        1         1         0       1
# 181673  START Primary Collection        0         1         0       1
# 181675  START Primary Collection        0         1         1       1
# 181676  START Primary Collection        0         0         0       0
# 181681  START Primary Collection        0         0         0       0
# 181683  START Primary Collection        0         0         0       0
#
#                                          related  incidentno
# 0                                            NaN           1
# 15                                           NaN           1
# 59                                           NaN           1
# 62                                           NaN           1
# 80                                           NaN           1
# 111                                          NaN           1
# 119                                          NaN           1
# 161                                          NaN           1
# 171                                          NaN           1
# 223                                          NaN           1
# 253                                          NaN           1
# 274                                          NaN           1
# 277                                          NaN           1
# 291                                          NaN           1
# 299                                          NaN           1
# 307                                          NaN           1
# 311                                          NaN           1
# 316                                          NaN           1
# 324                                          NaN           1
# 325                                          NaN           1
# 329                                          NaN           1
# 334                                          NaN           1
# 335                                          NaN           1
# 341                                          NaN           1
# 357                                          NaN           1
# 358                                          NaN           1
# 364                                          NaN           1
# 365                                          NaN           1
# 366                                          NaN           1
# 367                                          NaN           1
# ...                                          ...         ...
# 181580                                       NaN           1
# 181581                                       NaN           1
# 181585                                       NaN           1
# 181588                                       NaN           1
# 181592                                       NaN           1
# 181595                                       NaN           1
# 181600                                       NaN           1
# 181602                                       NaN           1
# 181604                                       NaN           1
# 181605                                       NaN           1
# 181616                                       NaN           1
# 181619                                       NaN           1
# 181623                                       NaN           1
# 181624                201712290002, 201712290003           1
# 181625                201712290002, 201712290003           1
# 181630                                       NaN           1
# 181636                                       NaN           1
# 181639  201712290022, 201712290023, 201712290024           1
# 181653                                       NaN           1
# 181654                                       NaN           1
# 181656                                       NaN           1
# 181666                                       NaN           1
# 181670                                       NaN           1
# 181671                                       NaN           1
# 181672                                       NaN           1
# 181673                                       NaN           1
# 181675                                       NaN           1
# 181676                                       NaN           1
# 181681                                       NaN           1
# 181683                                       NaN           1
#
# [41370 rows x 136 columns]

# %%
for i in list(GDTclean.columns):
    print(i)
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# weaptype1_txt
# weapsubtype1
# weapsubtype1_txt
# weaptype2
# weaptype2_txt
# weapsubtype2
# weapsubtype2_txt
# weaptype3
# weaptype3_txt
# weapsubtype3
# weapsubtype3_txt
# weaptype4
# weaptype4_txt
# weapsubtype4
# weapsubtype4_txt
# weapdetail
# nkill
# nkillus
# nkillter
# nwound
# nwoundus
# nwoundte
# property
# propextent
# propextent_txt
# propvalue
# propcomment
# ishostkid
# nhostkid
# nhostkidus
# nhours
# ndays
# divert
# kidhijcountry
# ransom
# ransomamt
# ransomamtus
# ransompaid
# ransompaidus
# ransomnote
# hostkidoutcome
# hostkidoutcome_txt
# nreleased
# addnotes
# scite1
# scite2
# scite3
# dbsource
# INT_LOG
# INT_IDEO
# INT_MISC
# INT_ANY
# related
# incidentno

# %% [markdown]
# Then we load in the list of all terror groups that accounted for more than 100 deaths up until 2017. These were classified by using four different possible sources. Wikipedia, Encyclopedia of Terrorism by Combs and Slann, Encyclopedia of Terrorism by Kushner, The SAGE Encyclopedia of TERRORISM by GUS Martin

# %%
classification=pd.read_csv("TerrorGroups_Over100Deaths_2017_2.csv", encoding="latin-1")
classification
# Out:
#                                                  gname  nkill classification1  \
# 0                              Abdullah Azzam Brigades    178        islamist
# 1                         Abu Nidal Organization (ANO)    263      liberation
# 2                               Abu Sayyaf Group (ASG)    635      liberation
# 3             Adan-Abyan Province of the Islamic State    156        islamist
# 4             African National Congress (South Africa)    421      liberation
# 5                              Al-Aqsa Martyrs Brigade    276      liberation
# 6                         Al-Gama'at al-Islamiyya (IG)    492        islamist
# 7    Al-Mua'qi'oon Biddam Brigade (Those who Sign w...    115        islamist
# 8                                Al-Naqshabandiya Army    125        islamist
# 9                                      Al-Nusrah Front   1902        islamist
# 10                                            Al-Qaida   3770        islamist
# 11                                    Al-Qaida in Iraq   4016        islamist
# 12            Al-Qaida in the Arabian Peninsula (AQAP)   1689        islamist
# 13              Al-Qaida in the Islamic Maghreb (AQIM)    619        islamist
# 14                                          Al-Shabaab   5621        islamist
# 15                         Algerian Islamic Extremists    442             NaN
# 16                      Allied Democratic Forces (ADF)   1223        islamist
# 17                                  Ansar al-Din Front    206        islamist
# 18                             Ansar al-Sharia (Libya)    102             NaN
# 19                                      Ansar al-Sunna    141        islamist
# 20                                 Anti-Balaka Militia    535       christian
# 21                          Anti-Government extremists    256             NaN
# 22                          Anti-Government Guerrillas    143             NaN
# 23               Arakan Rohingya Salvation Army (ARSA)    142        islamist
# 24                           Armed Islamic Group (GIA)   1390        islamist
# 25                                  Asa'ib Ahl al-Haqq    116        islamist
# 26          Azawad National Liberation Movement (MNLA)    116      liberation
# 27                        Baloch Liberation Army (BLA)    256      liberation
# 28                       Baloch Liberation Front (BLF)    148      liberation
# 29                        Baloch Republican Army (BRA)    137      liberation
# ..                                                 ...    ...             ...
# 166                Sinai Province of the Islamic State   1145        islamist
# 167            Special Purpose Islamic Regiment (SPIR)    170        islamist
# 168              Sudan People's Liberation Army (SPLA)    181      liberation
# 169         Sudan People's Liberation Movement - North    261      liberation
# 170  Sudan People's Liberation Movement in Oppositi...   1084      liberation
# 171                            Sunni Muslim extremists    159             NaN
# 172                                            Taliban  23950        islamist
# 173                                 Taliban (Pakistan)    137        islamist
# 174                                             Tamils   1031             NaN
# 175                                   Tawhid and Jihad    810        islamist
# 176                    Tehrik-i-Taliban Pakistan (TTP)   4762             NaN
# 177                                         Terrorists    103             NaN
# 178                                  The Extraditables    180     drugrelated
# 179             Tigray Peoples Liberation Front (TPLF)    318        Far-left
# 180              Tripoli Province of the Islamic State    373        islamist
# 181                  Tripura National Volunteers (TNV)    150      liberation
# 182          Tupac Amaru Revolutionary Movement (MRTA)    186        Far-left
# 183                            Turkestan Islamic Party    108        islamist
# 184                                   Tutsi extremists    858             NaN
# 185                               Uganda People's Army    133      liberation
# 186                                 Uighur liberations    376             NaN
# 187                      Ulster Freedom Fighters (UFF)    179       christian
# 188                       Ulster Volunteer Force (UVF)    339       christian
# 189            Union for Peace in Central Africa (UPC)    223          ethnic
# 190  Union of Forces for Democracy and Development ...    103      liberation
# 191                           United Baloch Army (UBA)    157      liberation
# 192            United Liberation Front of Assam (ULFA)    564        Far-left
# 193        United Self Defense Units of Colombia (AUC)    328       Far-right
# 194                                    Vigilante Group    247             NaN
# 195                    Zimbabwe African People's Union    143        Far-left
#
#     classification2 classification3  \
# 0               NaN             NaN
# 1        liberation             NaN
# 2          islamist             NaN
# 3               NaN             NaN
# 4               NaN             NaN
# 5          Far-left             NaN
# 6               NaN             NaN
# 7               NaN             NaN
# 8        liberation             NaN
# 9               NaN             NaN
# 10              NaN             NaN
# 11              NaN             NaN
# 12              NaN             NaN
# 13              NaN             NaN
# 14       liberation             NaN
# 15              NaN             NaN
# 16       liberation             NaN
# 17              NaN             NaN
# 18              NaN             NaN
# 19       liberation             NaN
# 20              NaN             NaN
# 21              NaN             NaN
# 22              NaN             NaN
# 23       liberation             NaN
# 24       liberation             NaN
# 25              NaN             NaN
# 26       liberation             NaN
# 27       liberation             NaN
# 28       liberation             NaN
# 29       liberation             NaN
# ..              ...             ...
# 166      liberation             NaN
# 167      liberation      liberation
# 168             NaN             NaN
# 169             NaN             NaN
# 170             NaN             NaN
# 171             NaN             NaN
# 172      liberation             NaN
# 173      liberation             NaN
# 174             NaN             NaN
# 175             NaN             NaN
# 176             NaN             NaN
# 177             NaN             NaN
# 178             NaN             NaN
# 179             NaN             NaN
# 180      liberation             NaN
# 181             NaN             NaN
# 182      liberation             NaN
# 183      liberation             NaN
# 184             NaN             NaN
# 185             NaN             NaN
# 186             NaN             NaN
# 187       Far-right      liberation
# 188       Far-right      liberation
# 189             NaN             NaN
# 190             NaN             NaN
# 191             NaN             NaN
# 192      liberation          ethnic
# 193             NaN             NaN
# 194             NaN             NaN
# 195      liberation             NaN
#
#                                                source1  \
# 0    https://en.wikipedia.org/wiki/Abdullah_Azzam_B...
# 1                                              kushner
# 2                                          combs&slann
# 3    https://en.wikipedia.org/wiki/Aden-Abyan_Islam...
# 4    https://en.wikipedia.org/wiki/African_National...
# 5    https://en.wikipedia.org/wiki/Al-Aqsa_Martyrs%...
# 6    https://en.wikipedia.org/wiki/Al-Jama%27a_al-I...
# 7    https://en.wikipedia.org/wiki/Mokhtar_Belmokht...
# 8    https://en.wikipedia.org/wiki/Army_of_the_Men_...
# 9         https://en.wikipedia.org/wiki/Al-Nusra_Front
# 10                                             kushner
# 11   https://en.wikipedia.org/wiki/Tanzim_Qaidat_al...
# 12   https://en.wikipedia.org/wiki/Al-Qaeda_in_the_...
# 13   https://en.wikipedia.org/wiki/Al-Qaeda_in_the_...
# 14   https://en.wikipedia.org/wiki/Al-Shabaab_(mili...
# 15                                                 NaN
# 16   https://en.wikipedia.org/wiki/Allied_Democrati...
# 17    https://en.wikipedia.org/wiki/Ansar_al-Din_Front
# 18        https://en.wikipedia.org/wiki/Ansar_al-Islam
# 19   https://en.wikipedia.org/wiki/Jamaat_Ansar_al-...
# 20           https://en.wikipedia.org/wiki/Anti-balaka
# 21                                                 NaN
# 22                                                 NaN
# 23   https://en.wikipedia.org/wiki/Arakan_Rohingya_...
# 24   https://en.wikipedia.org/wiki/Armed_Islamic_Gr...
# 25      https://en.wikipedia.org/wiki/Asaib_Ahl_al-Haq
# 26   https://en.wikipedia.org/wiki/National_Movemen...
# 27   https://en.wikipedia.org/wiki/Balochistan_Libe...
# 28   https://en.wikipedia.org/wiki/Baluch_Liberatio...
# 29   https://en.wikipedia.org/wiki/Baloch_Republica...
# ..                                                 ...
# 166  https://en.wikipedia.org/wiki/Islamic_State_of...
# 167  https://en.wikipedia.org/wiki/Special_Purpose_...
# 168  https://en.wikipedia.org/wiki/Sudan_People%27s...
# 169  https://en.wikipedia.org/wiki/Sudan_People's_L...
# 170  https://en.wikipedia.org/wiki/Sudan_Peoples_Li...
# 171                                                NaN
# 172              https://en.wikipedia.org/wiki/Taliban
# 173  https://en.wikipedia.org/wiki/Tehrik-i-Taliban...
# 174                                                NaN
# 175  https://en.wikipedia.org/wiki/Jama%27at_al-Taw...
# 176  https://en.wikipedia.org/wiki/Tehrik-i-Taliban...
# 177                                                NaN
# 178    https://en.wikipedia.org/wiki/The_Extraditables
# 179  https://en.wikipedia.org/wiki/Tigray_People%27...
# 180  https://en.wikipedia.org/wiki/Islamic_State_of...
# 181  https://en.wikipedia.org/wiki/Tripura_National...
# 182  https://en.wikipedia.org/wiki/T%C3%BApac_Amaru...
# 183  https://en.wikipedia.org/wiki/Turkistan_Islami...
# 184                                                NaN
# 185  https://en.wikipedia.org/wiki/Uganda_People%27...
# 186  https://en.wikipedia.org/wiki/Turkistan_Islami...
# 187  https://en.wikipedia.org/wiki/Ulster_Defence_A...
# 188  https://en.wikipedia.org/wiki/Ulster_Volunteer...
# 189          https://en.wikipedia.org/wiki/Ali_Darassa
# 190  https://en.wikipedia.org/wiki/Union_of_Forces_...
# 191   https://en.wikipedia.org/wiki/United_Baloch_Army
# 192  https://en.wikipedia.org/wiki/United_Liberatio...
# 193  https://en.wikipedia.org/wiki/United_Self-Defe...
# 194                                                NaN
# 195  https://en.wikipedia.org/wiki/Zimbabwe_African...
#
#                    search_phrase1            source2  \
# 0                             NaN  Sage Encyclopedia
# 1    Abu Nidal Organization (ANO)  Sage Encyclopedia
# 2          Abu Sayyaf Group (ASG)            kushner
# 3                             NaN  Sage Encyclopedia
# 4                             NaN                NaN
# 5                             NaN  Sage Encyclopedia
# 6                             NaN  Sage Encyclopedia
# 7                             NaN                NaN
# 8                             NaN                NaN
# 9                             NaN  Sage Encyclopedia
# 10                            NaN  Sage Encyclopedia
# 11                            NaN  Sage Encyclopedia
# 12                            NaN  Sage Encyclopedia
# 13                            NaN  Sage Encyclopedia
# 14                            NaN  Sage Encyclopedia
# 15                            NaN                NaN
# 16                            NaN                NaN
# 17                            NaN                NaN
# 18                            NaN                NaN
# 19                            NaN  Sage Encyclopedia
# 20                            NaN                NaN
# 21                            NaN                NaN
# 22                            NaN                NaN
# 23                            NaN                NaN
# 24                            NaN        Combs&Slann
# 25                            NaN                NaN
# 26                            NaN                NaN
# 27                            NaN                NaN
# 28                            NaN                NaN
# 29                            NaN                NaN
# ..                            ...                ...
# 166                           NaN  Sage Encyclopedia
# 167                           NaN  Sage Encyclopedia
# 168                           NaN                NaN
# 169                           NaN                NaN
# 170                           NaN                NaN
# 171                           NaN                NaN
# 172                           NaN  Sage Encyclopedia
# 173                           NaN  Sage Encyclopedia
# 174                           NaN                NaN
# 175                           NaN  Sage Encyclopedia
# 176                           NaN  Sage Encyclopedia
# 177                           NaN                NaN
# 178                           NaN  Sage Encyclopedia
# 179                           NaN                NaN
# 180                           NaN  Sage Encyclopedia
# 181                           NaN                NaN
# 182                           NaN  Sage Encyclopedia
# 183                           NaN  Sage Encyclopedia
# 184                           NaN                NaN
# 185                           NaN                NaN
# 186                           NaN                NaN
# 187                           NaN  Sage Encyclopedia
# 188                           NaN  Sage Encyclopedia
# 189                           NaN                NaN
# 190                           NaN                NaN
# 191                           NaN                NaN
# 192                           NaN                NaN
# 193                           NaN  Sage Encyclopedia
# 194                           NaN                NaN
# 195                           NaN                NaN
#
#                                         search_phrase2
# 0                                       abdullah azzam
# 1                         Abu Nidal Organization (ANO)
# 2                               Abu Sayyaf Group (ASG)
# 3                              Aden-Abyan Islamic Army
# 4                                                  NaN
# 5                             AL AQSA MARTYRS BRIGADES
# 6                                  GAMAÕA AL ISLAMIYYA
# 7                                                  NaN
# 8                                                  NaN
# 9                                             Al Qaeda
# 10                                            Al Qaeda
# 11                                            Al Qaeda
# 12                                            Al Qaeda
# 13                                            Al Qaeda
# 14                                           AL SHABAB
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                      ANSAR AL ISLAM
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                           Armed Islamic Group (GIA)
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 166                                  AL QAEDA IN IRAQ
# 167                             Dubrovka theater siege
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
# 173                          TEHRIK-I-TALIBAN PAKISTAN
# 174                                                NaN
# 175                                  AL QAEDA IN IRAQ
# 176                          TEHRIK-I-TALIBAN PAKISTAN
# 177                                                NaN
# 178  in a series of spectacular political assassina...
# 179                                                NaN
# 180                                  AL QAEDA IN IRAQ
# 181                                                NaN
# 182                 Tupac Amaru Revolutionary Movement
# 183                    EAST TURKESTAN ISLAMIC MOVEMENT
# 184                                                NaN
# 185                                                NaN
# 186                                                NaN
# 187                            ULSTER FREEDOM FIGHTERS
# 188                             ULSTER VOLUNTEER FORCE
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
# 193                                                AUC
# 194                                                NaN
# 195                                                NaN
#
# [196 rows x 9 columns]

# %% [markdown]
# We only include the groups that were classified by two sources. Classification for one group can include up to two different ones. The list of possible classifications follows in the next code block

# %%
safeclassification=classification[(classification["source1"].notnull()) & (classification["source2"].notnull())]
safeclassification
# Out:
#                                                  gname  nkill classification1  \
# 0                              Abdullah Azzam Brigades    178        islamist
# 1                         Abu Nidal Organization (ANO)    263      liberation
# 2                               Abu Sayyaf Group (ASG)    635      liberation
# 3             Adan-Abyan Province of the Islamic State    156        islamist
# 5                              Al-Aqsa Martyrs Brigade    276      liberation
# 6                         Al-Gama'at al-Islamiyya (IG)    492        islamist
# 9                                      Al-Nusrah Front   1902        islamist
# 10                                            Al-Qaida   3770        islamist
# 11                                    Al-Qaida in Iraq   4016        islamist
# 12            Al-Qaida in the Arabian Peninsula (AQAP)   1689        islamist
# 13              Al-Qaida in the Islamic Maghreb (AQIM)    619        islamist
# 14                                          Al-Shabaab   5621        islamist
# 19                                      Ansar al-Sunna    141        islamist
# 24                           Armed Islamic Group (GIA)   1390        islamist
# 31                 Barqa Province of the Islamic State    205        islamist
# 32                 Basque Fatherland and Freedom (ETA)    727      liberation
# 34                                          Boko Haram  17903        islamist
# 35                                    Caucasus Emirate    227        islamist
# 39            Communist Party of Nepal- Maoist (CPN-M)    610        Far-left
# 42                                   Deccan Mujahideen    184        islamist
# 43   Democratic Front for the Liberation of Rwanda ...    414          ethnic
# 44                                             Dev Sol    118        Far-left
# 47    Farabundo Marti National Liberation Front (FMLN)   2323        Far-left
# 54             Hadramawt Province of the Islamic State    109        islamist
# 55                 Hamas (Islamic Resistance Movement)    763        islamist
# 57                             Harkatul Jihad-e-Islami    226        islamist
# 59                                           Hezbollah    749        islamist
# 60                              Hizbul Mujahideen (HM)    228        islamist
# 61                     Houthi extremists (Ansar Allah)   1822        islamist
# 66                         Irish Republican Army (IRA)   1069      liberation
# ..                                                 ...    ...             ...
# 130                              Nicaraguan Resistance    214       Far-right
# 133            Palestine Liberation Organization (PLO)    230      liberation
# 135                    Palestinian Islamic Jihad (PIJ)    233        islamist
# 139                 Patriotic Union of Kurdistan (PUK)    127          ethnic
# 140                  Peasant Self-Defense Group (ACCU)    313       Far-right
# 141                   People's Liberation Forces (FPL)    104        Far-left
# 144  Popular Front for the Liberation of Palestine ...    137        Far-left
# 145  Popular Front for the Liberation of Palestine,...    167        Far-left
# 146                      Popular Liberation Army (EPL)    285        Far-left
# 150      Revolutionary Armed Forces of Colombia (FARC)   3673        Far-left
# 151                   Revolutionary United Front (RUF)    470      liberation
# 155  Riyadus-Salikhin Reconnaissance and Sabotage B...    412        islamist
# 156   Salafist Group for Preaching and Fighting (GSPC)    387        islamist
# 157                Sanaa Province of the Islamic State    271        islamist
# 158        Sandinista National Liberation Front (FSLN)    120        Far-left
# 163                                  Shining Path (SL)   8077        Far-left
# 165  Simon Bolivar Guerrilla Coordinating Board (CGSB)    185        Far-left
# 166                Sinai Province of the Islamic State   1145        islamist
# 167            Special Purpose Islamic Regiment (SPIR)    170        islamist
# 172                                            Taliban  23950        islamist
# 173                                 Taliban (Pakistan)    137        islamist
# 175                                   Tawhid and Jihad    810        islamist
# 176                    Tehrik-i-Taliban Pakistan (TTP)   4762             NaN
# 178                                  The Extraditables    180     drugrelated
# 180              Tripoli Province of the Islamic State    373        islamist
# 182          Tupac Amaru Revolutionary Movement (MRTA)    186        Far-left
# 183                            Turkestan Islamic Party    108        islamist
# 187                      Ulster Freedom Fighters (UFF)    179       christian
# 188                       Ulster Volunteer Force (UVF)    339       christian
# 193        United Self Defense Units of Colombia (AUC)    328       Far-right
#
#     classification2 classification3  \
# 0               NaN             NaN
# 1        liberation             NaN
# 2          islamist             NaN
# 3               NaN             NaN
# 5          Far-left             NaN
# 6               NaN             NaN
# 9               NaN             NaN
# 10              NaN             NaN
# 11              NaN             NaN
# 12              NaN             NaN
# 13              NaN             NaN
# 14       liberation             NaN
# 19       liberation             NaN
# 24       liberation             NaN
# 31       liberation             NaN
# 32         Far-left             NaN
# 34       liberation             NaN
# 35       liberation             NaN
# 39       liberation             NaN
# 42       liberation             NaN
# 43       liberation             NaN
# 44              NaN             NaN
# 47              NaN             NaN
# 54              NaN             NaN
# 55       liberation             NaN
# 57              NaN             NaN
# 59       liberation    antisemitism
# 60         islamist             NaN
# 61         islamist    antisemitism
# 66        christian             NaN
# ..              ...             ...
# 130             NaN             NaN
# 133        Far-left             NaN
# 135      liberation             NaN
# 139      liberation        Far-left
# 140             NaN             NaN
# 141             NaN             NaN
# 144      liberation      liberation
# 145      liberation      liberation
# 146             NaN             NaN
# 150      liberation             NaN
# 151             NaN             NaN
# 155      liberation             NaN
# 156      liberation             NaN
# 157      liberation             NaN
# 158             NaN             NaN
# 163             NaN             NaN
# 165             NaN             NaN
# 166      liberation             NaN
# 167      liberation      liberation
# 172      liberation             NaN
# 173      liberation             NaN
# 175             NaN             NaN
# 176             NaN             NaN
# 178             NaN             NaN
# 180      liberation             NaN
# 182      liberation             NaN
# 183      liberation             NaN
# 187       Far-right      liberation
# 188       Far-right      liberation
# 193             NaN             NaN
#
#                                                source1  \
# 0    https://en.wikipedia.org/wiki/Abdullah_Azzam_B...
# 1                                              kushner
# 2                                          combs&slann
# 3    https://en.wikipedia.org/wiki/Aden-Abyan_Islam...
# 5    https://en.wikipedia.org/wiki/Al-Aqsa_Martyrs%...
# 6    https://en.wikipedia.org/wiki/Al-Jama%27a_al-I...
# 9         https://en.wikipedia.org/wiki/Al-Nusra_Front
# 10                                             kushner
# 11   https://en.wikipedia.org/wiki/Tanzim_Qaidat_al...
# 12   https://en.wikipedia.org/wiki/Al-Qaeda_in_the_...
# 13   https://en.wikipedia.org/wiki/Al-Qaeda_in_the_...
# 14   https://en.wikipedia.org/wiki/Al-Shabaab_(mili...
# 19   https://en.wikipedia.org/wiki/Jamaat_Ansar_al-...
# 24   https://en.wikipedia.org/wiki/Armed_Islamic_Gr...
# 31   https://en.wikipedia.org/wiki/Islamic_State_of...
# 32   https://en.wikipedia.org/wiki/ETA_(liberation_...
# 34            https://en.wikipedia.org/wiki/Boko_Haram
# 35      https://en.wikipedia.org/wiki/Caucasus_Emirate
# 39   https://en.wikipedia.org/wiki/Communist_Party_...
# 42   https://es.wikipedia.org/wiki/Muyahidines_del_...
# 43   https://en.wikipedia.org/wiki/Democratic_Force...
# 44   https://de.wikipedia.org/wiki/Devrimci_Sol#Akt...
# 47   https://en.wikipedia.org/wiki/Farabundo_Mart%C...
# 54   https://en.wikipedia.org/wiki/Al-Qaeda_in_the_...
# 55                 https://en.wikipedia.org/wiki/Hamas
# 57   https://en.wikipedia.org/wiki/Harkat-ul-Jihad_...
# 59             https://en.wikipedia.org/wiki/Hezbollah
# 60     https://en.wikipedia.org/wiki/Hizbul_Mujahideen
# 61               https://en.wikipedia.org/wiki/Houthis
# 66                                   Sage Encyclopedia
# ..                                                 ...
# 130              https://en.wikipedia.org/wiki/Contras
# 133  https://en.wikipedia.org/wiki/Palestine_Libera...
# 135  https://en.wikipedia.org/wiki/Islamic_Jihad_Mo...
# 139  https://en.wikipedia.org/wiki/Patriotic_Union_...
# 140  https://en.wikipedia.org/wiki/Peasant_Self-Def...
# 141  https://en.wikipedia.org/wiki/Fuerzas_Populare...
# 144  https://en.wikipedia.org/wiki/Popular_Front_fo...
# 145  https://en.wikipedia.org/wiki/Popular_Front_fo...
# 146  https://en.wikipedia.org/wiki/Popular_Liberati...
# 150  https://en.wikipedia.org/wiki/Revolutionary_Ar...
# 151  https://en.wikipedia.org/wiki/Revolutionary_Un...
# 155  https://en.wikipedia.org/wiki/Riyad-us_Salihee...
# 156  https://en.wikipedia.org/wiki/Salafist_Group_f...
# 157  https://en.wikipedia.org/wiki/Islamic_State_of...
# 158  https://en.wikipedia.org/wiki/Sandinista_Natio...
# 163         https://en.wikipedia.org/wiki/Shining_Path
# 165  https://en.wikipedia.org/wiki/Sim%C3%B3n_Bol%C...
# 166  https://en.wikipedia.org/wiki/Islamic_State_of...
# 167  https://en.wikipedia.org/wiki/Special_Purpose_...
# 172              https://en.wikipedia.org/wiki/Taliban
# 173  https://en.wikipedia.org/wiki/Tehrik-i-Taliban...
# 175  https://en.wikipedia.org/wiki/Jama%27at_al-Taw...
# 176  https://en.wikipedia.org/wiki/Tehrik-i-Taliban...
# 178    https://en.wikipedia.org/wiki/The_Extraditables
# 180  https://en.wikipedia.org/wiki/Islamic_State_of...
# 182  https://en.wikipedia.org/wiki/T%C3%BApac_Amaru...
# 183  https://en.wikipedia.org/wiki/Turkistan_Islami...
# 187  https://en.wikipedia.org/wiki/Ulster_Defence_A...
# 188  https://en.wikipedia.org/wiki/Ulster_Volunteer...
# 193  https://en.wikipedia.org/wiki/United_Self-Defe...
#
#                    search_phrase1            source2  \
# 0                             NaN  Sage Encyclopedia
# 1    Abu Nidal Organization (ANO)  Sage Encyclopedia
# 2          Abu Sayyaf Group (ASG)            kushner
# 3                             NaN  Sage Encyclopedia
# 5                             NaN  Sage Encyclopedia
# 6                             NaN  Sage Encyclopedia
# 9                             NaN  Sage Encyclopedia
# 10                            NaN  Sage Encyclopedia
# 11                            NaN  Sage Encyclopedia
# 12                            NaN  Sage Encyclopedia
# 13                            NaN  Sage Encyclopedia
# 14                            NaN  Sage Encyclopedia
# 19                            NaN  Sage Encyclopedia
# 24                            NaN        Combs&Slann
# 31                            NaN  Sage Encyclopedia
# 32                            NaN                ETA
# 34                            NaN  Sage Encyclopedia
# 35                            NaN  Sage Encyclopedia
# 39                            NaN  Sage Encyclopedia
# 42                            NaN  Sage Encyclopedia
# 43                            NaN  Sage Encyclopedia
# 44                            NaN  Sage Encyclopedia
# 47                            NaN            kushner
# 54                            NaN  Sage Encyclopedia
# 55                            NaN            Kushner
# 57                            NaN            Kushner
# 59                            NaN  Sage Encyclopedia
# 60                            NaN            kushner
# 61                            NaN  Sage Encyclopedia
# 66                            NaN        Combs&Slann
# ..                            ...                ...
# 130                           NaN  Sage Encyclopedia
# 133                           NaN        combs&slann
# 135                           NaN        combs&slann
# 139                           NaN  Sage Encyclopedia
# 140                           NaN  Sage Encyclopedia
# 141                           NaN  Sage Encyclopedia
# 144                           NaN            Kushner
# 145                           NaN            Kushner
# 146                           NaN  Sage Encyclopedia
# 150                           NaN        combs&slann
# 151                           NaN        combs&slann
# 155                           NaN  Sage Encyclopedia
# 156                           NaN  Sage Encyclopedia
# 157                           NaN  Sage Encyclopedia
# 158                           NaN  Sage Encyclopedia
# 163                           NaN            kushner
# 165                           NaN  Sage Encyclopedia
# 166                           NaN  Sage Encyclopedia
# 167                           NaN  Sage Encyclopedia
# 172                           NaN  Sage Encyclopedia
# 173                           NaN  Sage Encyclopedia
# 175                           NaN  Sage Encyclopedia
# 176                           NaN  Sage Encyclopedia
# 178                           NaN  Sage Encyclopedia
# 180                           NaN  Sage Encyclopedia
# 182                           NaN  Sage Encyclopedia
# 183                           NaN  Sage Encyclopedia
# 187                           NaN  Sage Encyclopedia
# 188                           NaN  Sage Encyclopedia
# 193                           NaN  Sage Encyclopedia
#
#                                         search_phrase2
# 0                                       abdullah azzam
# 1                         Abu Nidal Organization (ANO)
# 2                               Abu Sayyaf Group (ASG)
# 3                              Aden-Abyan Islamic Army
# 5                             AL AQSA MARTYRS BRIGADES
# 6                                  GAMAÕA AL ISLAMIYYA
# 9                                             Al Qaeda
# 10                                            Al Qaeda
# 11                                            Al Qaeda
# 12                                            Al Qaeda
# 13                                            Al Qaeda
# 14                                           AL SHABAB
# 19                                      ANSAR AL ISLAM
# 24                           Armed Islamic Group (GIA)
# 31                  known as the Islamic State of Iraq
# 32                                                 NaN
# 34   Islamic State in West Africa(Wiki)-> "known as...
# 35                                                 NaN
# 39                            Communist Party of Nepal
# 42                                       Mumbai Attack
# 43                                                 NaN
# 44       REVOLUTIONARY PEOPLEÕS LIBERATION PARTY/FRONT
# 47           Farabundo Marti National Liberation Front
# 54   William Long(Wiki)->LONG, WILLIAM ANDREW, MURD...
# 55                                                 NaN
# 57                              Harakat ul-Mujahideen
# 59                                                 NaN
# 60                                                 NaN
# 61                                           hezbollah
# 66                                                 NaN
# ..                                                 ...
# 130                                 Nicaraguan Contras
# 133                                                NaN
# 135                                                NaN
# 139                                                NaN
# 140             UNITED SELF-DEFENSE FORCES OF COLOMBIA
# 141          FARABUNDO MART! NATIONAL LIBERATION FRONT
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
# 150                                                NaN
# 151                                                NaN
# 155                                Beslan school siege
# 156  Previously known as the Salafist Group for Pre...
# 157                                  AL QAEDA IN IRAQ
# 158                the Sandinista regime in Nicaragua.
# 163                                                NaN
# 165                      MAY 19 COMMUNIST ORGANIZATION
# 166                                  AL QAEDA IN IRAQ
# 167                             Dubrovka theater siege
# 172                                                NaN
# 173                          TEHRIK-I-TALIBAN PAKISTAN
# 175                                  AL QAEDA IN IRAQ
# 176                          TEHRIK-I-TALIBAN PAKISTAN
# 178  in a series of spectacular political assassina...
# 180                                  AL QAEDA IN IRAQ
# 182                 Tupac Amaru Revolutionary Movement
# 183                    EAST TURKESTAN ISLAMIC MOVEMENT
# 187                            ULSTER FREEDOM FIGHTERS
# 188                             ULSTER VOLUNTEER FORCE
# 193                                                AUC
#
# [83 rows x 9 columns]

# %% [markdown]
# We create a list of all the classes that exist in our group list

# %%
classlist=[]
a=classification["classification1"].unique().tolist()
b=classification["classification2"].unique().tolist()
c=classification["classification3"].unique().tolist()
classlist.extend(a)
classlist.extend(b)
classlist.extend(c)
classlist = [classlist for classlist in classlist if str(classlist) != 'nan']
classlist=set(classlist)
(classlist)
# Out:
# {'Far-left',
#  'Far-right',
#  'Sikh',
#  'antisemitism',
#  'christian',
#  'drugrelated',
#  'ethnic',
#  'islamist',
#  'liberation'}

# %% [raw]
# This is now the big for-loop that calculates for each of our defined classes a bunch of statistics. I will break it down with inline comments

# %%
#we first create one big empty dataframe, in which we will add our data
wholedf=pd.DataFrame()
wholedf
#we go through the different classes defined in our classlist
for groupclass in classlist:
    #each of this classes is changed into a list 
    groupfilter=[groupclass]
    groupfilterclass=str(groupfilter).replace("[","").replace("]","")
    #now we create two separate lists. one with all groups that are part of the class and one with all the groups that are not part of the class 
    filtered_group=safeclassification[(safeclassification["classification1"].isin(groupfilter)) | (safeclassification["classification2"].isin(groupfilter))| (safeclassification["classification3"].isin(groupfilter))]
    nongroup=safeclassification[~((safeclassification["classification1"].isin(groupfilter)))&~((safeclassification["classification2"].isin(groupfilter)))&~((safeclassification["classification3"].isin(groupfilter)))]
    #we create a list of lists, with the groups of the class in one bracket and all the non-class groups in the other
    groupdual=[filtered_group,nongroup]
    i=0
    #now we filter our cleaned databases of all incicdents once for the groups in that class and once for the groups that were not in that class

    for group in groupdual:
        i+=1
        if i==1:
            groupno=len(group)
            grouplist=group["gname"].tolist()
            groupGTD=GDTclean[(GDTclean["gname"].isin(grouplist))]
        
        if i==2:
            groupno=len(group)
            grouplist=group["gname"].tolist()
            groupGTD=GDTclean[(GDTclean["gname"].isin(grouplist))]
            groupfilterclass="non-"+groupfilterclass
            
        
            
        #after this filtering, we sum up all the incidents, we calculate the number of kills, wounds and suicides per incident
        incidents=groupGTD["incidentno"].sum()
        groupdeaths=groupGTD["nkill"].sum()/groupGTD["incidentno"].sum()
        groupdwounds=groupGTD["nwound"].sum()/groupGTD["incidentno"].sum()
        suiciderate=(groupGTD["suicide"].sum()/groupGTD["incidentno"].sum())
        #we create a dataframe that is a wide-table
        listdf=[("groups",[grouplist]),("groupno",[groupno]),("incidents",[incidents]),("deaths_per_attack",[groupdeaths]),("wound_per_attack",[groupdwounds]),("suiciderate",[suiciderate])]
        #transpose it
        groupstats=pd.DataFrame.from_items(listdf).transpose()
        #and rename the column to the name of the class
        groupstats=groupstats.rename(columns={0:groupfilterclass})
        #now we check for the frequency of mentions of countries
        dictionary={}
        #we count the frequencies of certain words being listed
        test=groupGTD['country_txt'].value_counts()
        type(test)
        #then we go through this dataframe, use it to fill a dictionary
        for key in test.index:
            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])
        #from which we fill a dataframe, then sort the dataframe and take the first five countries
        df=pd.DataFrame(dictionary , index=[0]).transpose()
        df=df.sort_values(by=0, ascending=False)
        df=df[:5]
        #then we rename the column by the class_name
        df=df.rename(columns={0:groupfilterclass})
        #and add this dataframe under the one we calculated already
        groupstats=pd.concat([groupstats,df])

        #this, we do now as well for other categories such as weapons, weaponsubtypes, targets, targetsubtypes
        dictionary={}
        test=groupGTD['weaptype1_txt'].value_counts()
        #this dictionary is especially important for these categories, where one value of a variable could be in multiple columns
        #here, we want to be sure that for example "explosives" are counted whether they are in column "weaptype1_txt", "weaptype2_txt","weaptype3_txt",
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])

        test=groupGTD['weaptype2_txt'].value_counts()
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])


        test=groupGTD['weaptype3_txt'].value_counts()
        type(test)
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])
        df=pd.DataFrame(dictionary , index=[0]).transpose()
        df=df.sort_values(by=0, ascending=False)

        df=df[:5]
        df=df.rename(columns={0:groupfilterclass})
        groupstats=pd.concat([groupstats,df])
        #GDTclean.groupby('').count()
        dictionary={}
        test=groupGTD['weapsubtype1_txt'].value_counts()
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])

        test=groupGTD['weapsubtype2_txt'].value_counts()
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])


        test=groupGTD['weapsubtype3_txt'].value_counts()
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])
        df=pd.DataFrame(dictionary , index=[0]).transpose()
        df=df.sort_values(by=0, ascending=False)

        df=df[:5]
        df=df.rename(columns={0:groupfilterclass})
        groupstats=pd.concat([groupstats,df])
        #GDTclean.groupby('').count()
        dictionary={}
        test=groupGTD['targtype1_txt'].value_counts()
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])

        test=groupGTD['targtype2_txt'].value_counts()
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])


        test=groupGTD['targtype3_txt'].value_counts()
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])
        df=pd.DataFrame(dictionary , index=[0]).transpose()
        df=df.sort_values(by=0, ascending=False)

        df=df[:5]
        df=df.rename(columns={0:groupfilterclass})
        groupstats=pd.concat([groupstats,df])

        #GDTclean.groupby('').count()
        dictionary={}
        test=groupGTD['targsubtype1_txt'].value_counts()
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])

        test=groupGTD['targsubtype2_txt'].value_counts()
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])


        test=groupGTD['targsubtype3_txt'].value_counts()
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])
        df=pd.DataFrame(dictionary , index=[0]).transpose()
        df=df.sort_values(by=0, ascending=False)

        df=df[:5]
        df=df.rename(columns={0:groupfilterclass})
        groupstats=pd.concat([groupstats,df])
        groupstats=groupstats.reset_index()
        groupstats=groupstats.rename(columns={"index":(groupclass)+"_categories"})
        #and then write this to a class specific csv
        groupstats.to_csv("{}_groupVSnogroup.csv".format(groupfilterclass))
        #also we add this dataframe on the left side of our empty dataframe from the very beginning
        #so from left to right, we fill up the dataframe
        wholedf = pd.concat([wholedf, groupstats], axis=1)
wholedf.to_csv("wholedf_groupVSnogroup.csv", encoding="utf-8")
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in double_scalars
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in double_scalars
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in long_scalars

# %% [markdown]
# This block does the exact same thing but just compares the group with ALL cases of the dataset that met the first set of criterias. This is opposed to the group and non-group approach up there.

# %%
#we first create one big empty dataframe, in which we will add our data
wholedf=pd.DataFrame()
wholedf
#we go through the different classes defined in our classlist
for groupclass in classlist:
    #each of this classes is changed into a list 
    groupfilter=[groupclass]
    groupfilterclass=str(groupfilter).replace("[","").replace("]","")
    #now we create two separate lists. one with all groups that are part of the class and one with all the groups that are not part of the class 
    filtered_group=safeclassification[(safeclassification["classification1"].isin(groupfilter)) | (safeclassification["classification2"].isin(groupfilter))| (safeclassification["classification3"].isin(groupfilter))]
    nongroup=safeclassification[~((safeclassification["classification1"].isin(groupfilter)))&~((safeclassification["classification2"].isin(groupfilter)))&~((safeclassification["classification3"].isin(groupfilter)))]
    #we create a list of lists, with the groups of the class in one bracket and all the non-class groups in the other
    groupdual=[filtered_group,nongroup]
    i=0
    #now we filter our cleaned databases of all incicdents once for the groups in that class and once for the groups that were not in that class

    for group in groupdual:
        i+=1
        if i==1:
            groupno=len(group)
            grouplist=group["gname"].tolist()
            groupGTD=GDTclean[(GDTclean["gname"].isin(grouplist))]
        
        if i==2:
            groupno=(len(GDTclean["gname"].unique()))-len(group)
            grouplist=group["gname"].tolist()
            #THIS IS THE KEY DIFFERENCE. ALL CASES THAT ARE NOT PART OF THE GROUPLIST ARE INCLUDED NOW
            groupGTD=GDTclean[(~GDTclean["gname"].isin(grouplist))]
            groupfilterclass="non-"+groupfilterclass
            
        
            
        #after this filtering, we sum up all the incidents, we calculate the number of kills, wounds and suicides per incident
        incidents=groupGTD["incidentno"].sum()
        groupdeaths=groupGTD["nkill"].sum()/groupGTD["incidentno"].sum()
        groupdwounds=groupGTD["nwound"].sum()/groupGTD["incidentno"].sum()
        suiciderate=(groupGTD["suicide"].sum()/groupGTD["incidentno"].sum())
        print(groupfilterclass)
        print(groupGTD["gname"].head())
        print(suiciderate)

        #we create a dataframe that is a wide-table
        listdf=[("groups",[grouplist]),("groupno",[groupno]),("incidents",[incidents]),("deaths_per_attack",[groupdeaths]),("wound_per_attack",[groupdwounds]),("suiciderate",[suiciderate])]
        #transpose it
        groupstats=pd.DataFrame.from_items(listdf).transpose()
        #and rename the column to the name of the class
        groupstats=groupstats.rename(columns={0:groupfilterclass})
        #now we check for the frequency of mentions of countries
        dictionary={}
        #we count the frequencies of certain words being listed
        test=groupGTD['country_txt'].value_counts()
        type(test)
        #then we go through this dataframe, use it to fill a dictionary
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])
        #from which we fill a dataframe, then sort the dataframe and take the first five countries
        df=pd.DataFrame(dictionary , index=[0]).transpose()
        df=df.sort_values(by=0, ascending=False)
        df=df[:5]
        #then we rename the column by the class_name
        df=df.rename(columns={0:groupfilterclass})
        #and add this dataframe under the one we calculated already
        groupstats=pd.concat([groupstats,df])

        #this, we do now as well for other categories such as weapons, weaponsubtypes, targets, targetsubtypes
        dictionary={}
        test=groupGTD['weaptype1_txt'].value_counts()
        type(test)
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])

        test=groupGTD['weaptype2_txt'].value_counts()
        type(test)
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])


        test=groupGTD['weaptype3_txt'].value_counts()
        type(test)
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])
        df=pd.DataFrame(dictionary , index=[0]).transpose()
        df=df.sort_values(by=0, ascending=False)

        df=df[:5]
        df=df.rename(columns={0:groupfilterclass})
        groupstats=pd.concat([groupstats,df])
        #GDTclean.groupby('').count()
        dictionary={}
        test=groupGTD['weapsubtype1_txt'].value_counts()
        type(test)
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])

        test=groupGTD['weapsubtype2_txt'].value_counts()
        type(test)
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])


        test=groupGTD['weapsubtype3_txt'].value_counts()
        type(test)
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])
        df=pd.DataFrame(dictionary , index=[0]).transpose()
        df=df.sort_values(by=0, ascending=False)

        df=df[:5]
        df=df.rename(columns={0:groupfilterclass})
        groupstats=pd.concat([groupstats,df])
        #GDTclean.groupby('').count()
        dictionary={}
        test=groupGTD['targtype1_txt'].value_counts()
        type(test)
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])

        test=groupGTD['targtype2_txt'].value_counts()
        type(test)
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])


        test=groupGTD['targtype3_txt'].value_counts()
        type(test)
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])
        df=pd.DataFrame(dictionary , index=[0]).transpose()
        df=df.sort_values(by=0, ascending=False)

        df=df[:5]
        df=df.rename(columns={0:groupfilterclass})
        groupstats=pd.concat([groupstats,df])

        #GDTclean.groupby('').count()
        dictionary={}
        test=groupGTD['targsubtype1_txt'].value_counts()
        type(test)
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])

        test=groupGTD['targsubtype2_txt'].value_counts()
        type(test)
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])


        test=groupGTD['targsubtype3_txt'].value_counts()
        type(test)
        for key in test.index:

            if key in dictionary:
                dictionary[key] += (test[key])
            else:
                dictionary[key] = (test[key])
        df=pd.DataFrame(dictionary , index=[0]).transpose()
        df=df.sort_values(by=0, ascending=False)

        df=df[:5]
        df=df.rename(columns={0:groupfilterclass})
        groupstats=pd.concat([groupstats,df])
        groupstats=groupstats.reset_index()
        groupstats=groupstats.rename(columns={"index":(groupclass)+"_categories"})
        #and then write this to a class specific csv
        groupstats.to_csv("{}_against_all_cases.csv".format(groupfilterclass))
        #also we add this dataframe on the left side of our empty dataframe from the very beginning
        #so from left to right, we fill up the dataframe
        wholedf = pd.concat([wholedf, groupstats], axis=1)
wholedf.to_csv("wholedf_against_all_cases.csv", encoding="utf-8")
# Out:
# 'christian'
# 364     Irish Republican Army (IRA)
# 365     Irish Republican Army (IRA)
# 366     Irish Republican Army (IRA)
# 367     Irish Republican Army (IRA)
# 368    Ulster Volunteer Force (UVF)
# Name: gname, dtype: object
# 0.0
# non-'christian'
# 0                                     MANO-D
# 15                                 Commune 1
# 111            Armed Commandos of Liberation
# 119                       Black Nationalists
# 161    Rebel Armed Forces of Guatemala (FAR)
# Name: gname, dtype: object
# 0.020084304487974214
# 'antisemitism'
# 18572    Hezbollah
# 20451    Hezbollah
# 20453    Hezbollah
# 20456    Hezbollah
# 20742    Hezbollah
# Name: gname, dtype: object
# 0.017793594306049824
# non-'antisemitism'
# 0                                     MANO-D
# 15                                 Commune 1
# 111            Armed Commandos of Liberation
# 119                       Black Nationalists
# 161    Rebel Armed Forces of Guatemala (FAR)
# Name: gname, dtype: object
# 0.022034569204380527
# 'liberation'
# 59     Popular Front for the Liberation of Palestine ...
# 62     Popular Front for the Liberation of Palestine ...
# 80     Popular Front for the Liberation of Palestine,...
# 329    Popular Front for the Liberation of Palestine ...
# 334    Popular Front for the Liberation of Palestine ...
# Name: gname, dtype: object
# 0.11849147201520532
# non-'liberation'
# 0                                                MANO-D
# 15                                            Commune 1
# 59    Popular Front for the Liberation of Palestine ...
# 62    Popular Front for the Liberation of Palestine ...
# 80    Popular Front for the Liberation of Palestine,...
# Name: gname, dtype: object
# 0.07785712220648183
# 'drugrelated'
# 39030    The Extraditables
# 39257    The Extraditables
# 39280    The Extraditables
# 39281    The Extraditables
# 39396    The Extraditables
# Name: gname, dtype: object
# 0.0
# non-'drugrelated'
# 0                                     MANO-D
# 15                                 Commune 1
# 111            Armed Commandos of Liberation
# 119                       Black Nationalists
# 161    Rebel Armed Forces of Guatemala (FAR)
# Name: gname, dtype: object
# 0.022165971129506738
# 'ethnic'
# 3141     Liberation Tigers of Tamil Eelam (LTTE)
# 7512     Liberation Tigers of Tamil Eelam (LTTE)
# 7889     Liberation Tigers of Tamil Eelam (LTTE)
# 13522         Patriotic Union of Kurdistan (PUK)
# 18443    Liberation Tigers of Tamil Eelam (LTTE)
# Name: gname, dtype: object
# 0.05022321428571429
# non-'ethnic'
# 0                                     MANO-D
# 15                                 Commune 1
# 111            Armed Commandos of Liberation
# 119                       Black Nationalists
# 161    Rebel Armed Forces of Guatemala (FAR)
# Name: gname, dtype: object
# 0.025262387112521358
# 'islamist'
# 1319    Mujahedin-e Khalq (MEK)
# 2510    Mujahedin-e Khalq (MEK)
# 2857    Mujahedin-e Khalq (MEK)
# 2882    Mujahedin-e Khalq (MEK)
# 3028    Mujahedin-e Khalq (MEK)
# Name: gname, dtype: object
# 0.1671245128729317
# non-'islamist'
# 0                                     MANO-D
# 15                                 Commune 1
# 111            Armed Commandos of Liberation
# 119                       Black Nationalists
# 161    Rebel Armed Forces of Guatemala (FAR)
# Name: gname, dtype: object
# 0.09719329564613706
# 'Sikh'
# Series([], Name: gname, dtype: object)
# nan
# non-'Sikh'
# 0                                     MANO-D
# 15                                 Commune 1
# 111            Armed Commandos of Liberation
# 119                       Black Nationalists
# 161    Rebel Armed Forces of Guatemala (FAR)
# Name: gname, dtype: object
# 0.022197862428062484
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in double_scalars
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in double_scalars
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in long_scalars
# 'Far-left'
# 59     Popular Front for the Liberation of Palestine ...
# 62     Popular Front for the Liberation of Palestine ...
# 80     Popular Front for the Liberation of Palestine,...
# 329    Popular Front for the Liberation of Palestine ...
# 334    Popular Front for the Liberation of Palestine ...
# Name: gname, dtype: object
# 0.01413710322752734
# non-'Far-left'
# 0                                                MANO-D
# 15                                            Commune 1
# 59    Popular Front for the Liberation of Palestine ...
# 62    Popular Front for the Liberation of Palestine ...
# 80    Popular Front for the Liberation of Palestine,...
# Name: gname, dtype: object
# 0.019462297456322983
# 'Far-right'
# 368     Ulster Volunteer Force (UVF)
# 1042    Ulster Volunteer Force (UVF)
# 1099    Ulster Volunteer Force (UVF)
# 1115    Ulster Volunteer Force (UVF)
# 1207    Ulster Volunteer Force (UVF)
# Name: gname, dtype: object
# 0.014207650273224045
# non-'Far-right'
# 0                                     MANO-D
# 15                                 Commune 1
# 111            Armed Commandos of Liberation
# 119                       Black Nationalists
# 161    Rebel Armed Forces of Guatemala (FAR)
# Name: gname, dtype: object
# 0.02172651666559216

# %% [markdown]
# This block is specifically to check if islamistic together with liberation-motives are even more brutal attacks (not the case)

# %%
#we first create one big empty dataframe, in which we will add our data
wholedf=pd.DataFrame()
wholedf
groupclass =  'islamist'
#each of this classes is changed into a list 
groupfilter=[groupclass]
groupfilterclass=str(groupfilter).replace("[","").replace("]","")

groupclass2 =  'liberation'
#each of this classes is changed into a list 
groupfilter2=[groupclass2]
groupfilterclass2=str(groupfilter2).replace("[","").replace("]","")
#now we create two separate lists. one with all groups that are part of the class and one with all the groups that are not part of the class 
filtered_groupA=safeclassification[(safeclassification["classification1"].isin(groupfilter)) | (safeclassification["classification2"].isin(groupfilter))| (safeclassification["classification3"].isin(groupfilter))]
filtered_group=filtered_groupA[(filtered_groupA["classification1"].isin(groupfilter2)) | (filtered_groupA["classification2"].isin(groupfilter2))| (filtered_groupA["classification3"].isin(groupfilter2))]

nongroupA=safeclassification[~((safeclassification["classification1"].isin(groupfilter)))&~((safeclassification["classification2"].isin(groupfilter)))&~((safeclassification["classification3"].isin(groupfilter)))]
nongroup=nongroupA[~((nongroupA["classification1"].isin(groupfilter2)))&~((nongroupA["classification2"].isin(groupfilter2)))&~((nongroupA["classification3"].isin(groupfilter2)))]
#we create a list of lists, with the groups of the class in one bracket and all the non-class groups in the other
groupdual=[filtered_group,nongroup]
i=0
#now we filter our cleaned databases of all incicdents once for the groups in that class and once for the groups that were not in that class

for group in groupdual:
    i+=1
    if i==1:
        groupno=len(group)
        grouplist=group["gname"].tolist()
        groupGTD=GDTclean[(GDTclean["gname"].isin(grouplist))]
        groupfilterclass=groupfilterclass+"and"+groupfilterclass2

        terrorgroup=groupGTD

    if i==2:
        groupno=len(group)
        grouplist=group["gname"].tolist()
        groupGTD=GDTclean[(GDTclean["gname"].isin(grouplist))]
        groupfilterclass="non-"+groupfilterclass+"and"+groupfilterclass2
        nonterrorgroup=groupGTD



    #after this filtering, we sum up all the incidents, we calculate the number of kills, wounds and suicides per incident
    incidents=groupGTD["incidentno"].sum()
    groupdeaths=groupGTD["nkill"].sum()/groupGTD["incidentno"].sum()
    groupdwounds=groupGTD["nwound"].sum()/groupGTD["incidentno"].sum()
    suiciderate=(groupGTD["suicide"].sum()/groupGTD["incidentno"].sum())
    #we create a dataframe that is a wide-table
    listdf=[("groups",[grouplist]),("groupno",[groupno]),("incidents",[incidents]),("deaths_per_attack",[groupdeaths]),("wound_per_attack",[groupdwounds]),("suiciderate",[suiciderate])]
    #transpose it
    groupstats=pd.DataFrame.from_items(listdf).transpose()
    #and rename the column to the name of the class
    groupstats=groupstats.rename(columns={0:groupfilterclass})
    #now we check for the frequency of mentions of countries
    dictionary={}
    #we count the frequencies of certain words being listed
    test=groupGTD['country_txt'].value_counts()
    type(test)
    #then we go through this dataframe, use it to fill a dictionary
    for key in test.index:

        if key in dictionary:
            dictionary[key] += (test[key])
        else:
            dictionary[key] = (test[key])
    #from which we fill a dataframe, then sort the dataframe and take the first five countries
    df=pd.DataFrame(dictionary , index=[0]).transpose()
    df=df.sort_values(by=0, ascending=False)
    df=df[:5]
    #then we rename the column by the class_name
    df=df.rename(columns={0:groupfilterclass})
    #and add this dataframe under the one we calculated already
    groupstats=pd.concat([groupstats,df])

    #this, we do now as well for other categories such as weapons, weaponsubtypes, targets, targetsubtypes
    dictionary={}
    test=groupGTD['weaptype1_txt'].value_counts()
    #this dictionary is especially important for these categories, where one value of a variable could be in multiple columns
    #here, we want to be sure that for example "explosives" are counted whether they are in column "weaptype1_txt", "weaptype2_txt","weaptype3_txt",
    for key in test.index:

        if key in dictionary:
            dictionary[key] += (test[key])
        else:
            dictionary[key] = (test[key])

    test=groupGTD['weaptype2_txt'].value_counts()
    for key in test.index:

        if key in dictionary:
            dictionary[key] += (test[key])
        else:
            dictionary[key] = (test[key])


    test=groupGTD['weaptype3_txt'].value_counts()
    type(test)
    for key in test.index:

        if key in dictionary:
            dictionary[key] += (test[key])
        else:
            dictionary[key] = (test[key])
    df=pd.DataFrame(dictionary , index=[0]).transpose()
    df=df.sort_values(by=0, ascending=False)

    df=df[:5]
    df=df.rename(columns={0:groupfilterclass})
    groupstats=pd.concat([groupstats,df])
    #GDTclean.groupby('').count()
    dictionary={}
    test=groupGTD['weapsubtype1_txt'].value_counts()
    for key in test.index:

        if key in dictionary:
            dictionary[key] += (test[key])
        else:
            dictionary[key] = (test[key])

    test=groupGTD['weapsubtype2_txt'].value_counts()
    for key in test.index:

        if key in dictionary:
            dictionary[key] += (test[key])
        else:
            dictionary[key] = (test[key])


    test=groupGTD['weapsubtype3_txt'].value_counts()
    for key in test.index:

        if key in dictionary:
            dictionary[key] += (test[key])
        else:
            dictionary[key] = (test[key])
    df=pd.DataFrame(dictionary , index=[0]).transpose()
    df=df.sort_values(by=0, ascending=False)

    df=df[:5]
    df=df.rename(columns={0:groupfilterclass})
    groupstats=pd.concat([groupstats,df])
    #GDTclean.groupby('').count()
    dictionary={}
    test=groupGTD['targtype1_txt'].value_counts()
    for key in test.index:

        if key in dictionary:
            dictionary[key] += (test[key])
        else:
            dictionary[key] = (test[key])

    test=groupGTD['targtype2_txt'].value_counts()
    for key in test.index:

        if key in dictionary:
            dictionary[key] += (test[key])
        else:
            dictionary[key] = (test[key])


    test=groupGTD['targtype3_txt'].value_counts()
    for key in test.index:

        if key in dictionary:
            dictionary[key] += (test[key])
        else:
            dictionary[key] = (test[key])
    df=pd.DataFrame(dictionary , index=[0]).transpose()
    df=df.sort_values(by=0, ascending=False)

    df=df[:5]
    df=df.rename(columns={0:groupfilterclass})
    groupstats=pd.concat([groupstats,df])

    #GDTclean.groupby('').count()
    dictionary={}
    test=groupGTD['targsubtype1_txt'].value_counts()
    for key in test.index:

        if key in dictionary:
            dictionary[key] += (test[key])
        else:
            dictionary[key] = (test[key])

    test=groupGTD['targsubtype2_txt'].value_counts()
    for key in test.index:

        if key in dictionary:
            dictionary[key] += (test[key])
        else:
            dictionary[key] = (test[key])


    test=groupGTD['targsubtype3_txt'].value_counts()
    for key in test.index:

        if key in dictionary:
            dictionary[key] += (test[key])
        else:
            dictionary[key] = (test[key])
    df=pd.DataFrame(dictionary , index=[0]).transpose()
    df=df.sort_values(by=0, ascending=False)

    df=df[:5]
    df=df.rename(columns={0:groupfilterclass})
    groupstats=pd.concat([groupstats,df])
    groupstats=groupstats.reset_index()
    groupstats=groupstats.rename(columns={"index":(groupclass)+"_categories"})
    #and then write this to a class specific csv
    groupstats.to_csv("{}_doublegroupVSnogroup.csv".format(groupfilterclass))
    #also we add this dataframe on the left side of our empty dataframe from the very beginning
    #so from left to right, we fill up the dataframe
    wholedf = pd.concat([wholedf, groupstats], axis=1)

# %%
wholedf
# Out:
#                                 islamist_categories  \
# 0                                            groups
# 1                                           groupno
# 2                                         incidents
# 3                                 deaths_per_attack
# 4                                  wound_per_attack
# 5                                       suiciderate
# 6                                       Afghanistan
# 7                                              Iraq
# 8                                           Nigeria
# 9                                           Somalia
# 10                                      Philippines
# 11                                       Explosives
# 12                                         Firearms
# 13                                          Unknown
# 14                                       Incendiary
# 15                                            Melee
# 16                                 Unknown Gun Type
# 17                                          Vehicle
# 18                           Unknown Explosive Type
# 19          Suicide (carried bodily by human being)
# 20        Projectile (rockets, mortars, RPGs, etc.)
# 21                      Private Citizens & Property
# 22                                           Police
# 23                             Government (General)
# 24                                         Military
# 25                                         Business
# 26                     Unnamed Civilian/Unspecified
# 27                         Village/City/Town/Suburb
# 28                  Police Security Forces/Officers
# 29  Police Building (headquarters, station, school)
# 30                                Police Checkpoint
#
#                             'islamist'and'liberation'  \
# 0   [Abu Sayyaf Group (ASG), Al-Shabaab, Ansar al-...
# 1                                                  27
# 2                                               13212
# 3                                             6.59968
# 4                                             6.07531
# 5                                            0.169391
# 6                                                4843
# 7                                                2947
# 8                                                1579
# 9                                                1211
# 10                                                375
# 11                                               6557
# 12                                               5424
# 13                                               2196
# 14                                                694
# 15                                                518
# 16                                               4382
# 17                                               1733
# 18                                               1364
# 19                                               1251
# 20                                                929
# 21                                               6263
# 22                                               3555
# 23                                               1395
# 24                                               1282
# 25                                                828
# 26                                               2612
# 27                                               1321
# 28                                               1301
# 29                                                961
# 30                                                739
#
#                                   islamist_categories  \
# 0                                              groups
# 1                                             groupno
# 2                                           incidents
# 3                                   deaths_per_attack
# 4                                    wound_per_attack
# 5                                         suiciderate
# 6                                                Peru
# 7                                         El Salvador
# 8                                            Pakistan
# 9                                           Nicaragua
# 10                                           Colombia
# 11                                           Firearms
# 12                                         Explosives
# 13                                            Unknown
# 14                                         Incendiary
# 15                                              Melee
# 16                  Automatic or Semi-Automatic Rifle
# 17                             Unknown Explosive Type
# 18                                            Handgun
# 19                                   Unknown Gun Type
# 20            Suicide (carried bodily by human being)
# 21                        Private Citizens & Property
# 22                                             Police
# 23                               Government (General)
# 24                                           Business
# 25                                          Utilities
# 26                           Village/City/Town/Suburb
# 27                    Police Security Forces/Officers
# 28                                        Electricity
# 29                       Unnamed Civilian/Unspecified
# 30  Government Personnel (excluding police, military)
#
#          non-'islamist'and'liberation'and'liberation'
# 0   [Dev Sol, Farabundo Marti National Liberation ...
# 1                                                  13
# 2                                                4340
# 3                                             4.22926
# 4                                             2.76659
# 5                                           0.0345622
# 6                                                2063
# 7                                                 881
# 8                                                 706
# 9                                                 354
# 10                                                254
# 11                                               2870
# 12                                               1421
# 13                                                378
# 14                                                140
# 15                                                 83
# 16                                               1859
# 17                                                851
# 18                                                522
# 19                                                457
# 20                                                106
# 21                                               1457
# 22                                                868
# 23                                                670
# 24                                                507
# 25                                                303
# 26                                                693
# 27                                                407
# 28                                                291
# 29                                                278
# 30                                                252

# %% [markdown]
# Looking for cases that match the pattern

# %%
cases=terrorgroup[(terrorgroup["nkill"]==7) & (terrorgroup["nwound"]==8)]
cases
# Out:
#              eventid  iyear  imonth  iday           approxdate  extended  \
# 67865   199805260001   1998       5    26                  NaN         0
# 82012   200612120002   2006      12    12                  NaN         0
# 128449  201403080015   2014       3     9                  NaN         0
# 141534  201412130054   2014      12    13                  NaN         0
# 150390  201507090059   2015       7     9  2015-07-09 00:00:00         0
# 166637  201609030014   2016       9     2                  NaN         0
# 173083  201703180020   2017       3    18                  NaN         0
# 179981  201710250019   2017      10    25                  NaN         0
#
#        resolution  country  country_txt  region     ...      \
# 67865         NaN        6      Algeria      10     ...
# 82012         NaN        4  Afghanistan       6     ...
# 128449        NaN        4  Afghanistan       6     ...
# 141534        NaN       95         Iraq      10     ...
# 150390        NaN        4  Afghanistan       6     ...
# 166637        NaN        4  Afghanistan       6     ...
# 173083        NaN      147      Nigeria      11     ...
# 179981        NaN        4  Afghanistan       6     ...
#
#                                                    scite1  \
# 67865   “Algeria wracked by new upsurge in clashes, bo...
# 82012   Six Killed in Afghan Suicide Attack at Provinc...
# 128449  "Afghanistan: 15 civilians killed or injured i...
# 141534  "ISIL fighters gaining ground in Anbar," Al Ja...
# 150390  "Taliban storms checkpoints in Ghazni," Afghan...
# 166637  "Highlights: Pakistan Pashto Press 3 September...
# 173083  "Triple Suicide Bomb Attack Kills 4 Civilians ...
# 179981  "Taliban, security forces suffer casualties du...
#
#                                                    scite2  \
# 67865   “Algiers bomb kills seven,” News Digest, May 2...
# 82012   "Afghan Taleban say governor target of suicide...
# 128449  "Afghanistan: Nine Civilians Killed, 8 Injured...
# 141534                                                NaN
# 150390                                                NaN
# 166637  "Seven militants killed in Afghanistan," Yahoo...
# 173083  "Suicide bombers kill mother, children in Born...
# 179981                                                NaN
#
#                                                    scite3  \
# 67865   “Seven die in Algeria when bomb explodes in ma...
# 82012                                                 NaN
# 128449  "Media Reports of Civilian Casualties in Afgha...
# 141534                                                NaN
# 150390                                                NaN
# 166637                                                NaN
# 173083  "Nigerian Suicide Bombers Kill 4," VOA News, M...
# 179981                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO  INT_MISC INT_ANY  \
# 67865                      CETIS        0         0         0       0
# 82012                      CETIS        0         0         0       0
# 128449  START Primary Collection        0         0         0       0
# 141534  START Primary Collection        0         1         0       1
# 150390  START Primary Collection        0         0         0       0
# 166637  START Primary Collection        0         0         0       0
# 173083  START Primary Collection        0         0         0       0
# 179981  START Primary Collection        0         0         0       0
#
#                                          related  incidentno
# 67865                                        NaN           1
# 82012                                        NaN           1
# 128449                                       NaN           1
# 141534                201412130053, 201412130054           1
# 150390  201507090057, 201507090058, 201507090059           1
# 166637                                       NaN           1
# 173083                                       NaN           1
# 179981                                       NaN           1
#
# [8 rows x 136 columns]

# %%
cases.to_csv("cases.csv")
