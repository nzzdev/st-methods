# %%
# coding: utf-8
import re
import os
import csv
import time
import requests
import random

from bs4 import BeautifulSoup as BS

find = re.compile(r"^(:*?)\..*")

yearlist=["2000-2001","2001-2002","2002-2003","2003-2004","2004-2005","2005-2006","2006-2007","2007-2008","2008-2009","2009-2010","2010-2011","2011-2012","2012-2013","2013-2014","2014-2015","2015-2016","2016-2017"]

for year in yearlist:
    newpath = "Football/"+year+"/" 
    if not os.path.exists(newpath):
        os.makedirs(newpath)
    with open((newpath+'savePL_{}.csv').format(year), 'w') as resultsfile:

        resultsfileWriter = csv.writer(resultsfile)
        firstrow=("kickoffdate","kickofftime","hometeam","hometeamgoals","awayteam","awayteamgoals")
        resultsfileWriter.writerow(firstrow)

        for daynumber in range(38):
                daynumber=daynumber+1
                link="http://www.worldfootball.net/schedule/eng-premier-league-{}-spieltag/{}/".format(year,daynumber)
                print(link)
                footie_page = requests.get(link).text
                soup = BS(footie_page, 'html.parser')
                soccer_table = soup.find('table', class_='standard_tabelle')
                #print(soccer_table)
                rows = soccer_table.find_all('tr')
                for row in rows:
                    date = row.find_all('td', {"align": "center", "nowrap":"nowrap"})
                    if(date[0].text)!="":
                        kickoffdate=(date[0].text)
                    kickofftime=(date[1].text)
                    #print(kickoffdate+" "+kickofftime)
                    hometeam = row.find_all('td')[2].text.replace('\n','')
                    awayteam = row.find_all('td')[4].text.replace('\n','')
                    #print(hometeam+"vs"+awayteam)
                    result = row.find_all('td')[5].text
                    #print(result)
                    character=""
                    hometeamgoals=""
                    awayteamgoals=""
                    i=-1
                    while(character!=":"):
                        hometeamgoals+=character
                        i+=1
                        character=str(result[i])
                    i+=1
                    character=str(result[i])
                    while(character!=" "):
                        awayteamgoals+=character
                        i+=1
                        character=str(result[i])

                    #print(hometeamgoals)
                    #print(awayteamgoals)
                    output_list=(kickoffdate,kickofftime,hometeam,hometeamgoals,awayteam,awayteamgoals)
                    resultsfileWriter.writerow(output_list)
# Out:
# http://www.worldfootball.net/schedule/eng-premier-league-2000-2001-spieltag/1/
# http://www.worldfootball.net/schedule/eng-premier-league-2000-2001-spieltag/2/
# http://www.worldfootball.net/schedule/eng-premier-league-2000-2001-spieltag/3/
# http://www.worldfootball.net/schedule/eng-premier-league-2000-2001-spieltag/4/
# http://www.worldfootball.net/schedule/eng-premier-league-2000-2001-spieltag/5/
# http://www.worldfootball.net/schedule/eng-premier-league-2000-2001-spieltag/6/
# http://www.worldfootball.net/schedule/eng-premier-league-2000-2001-spieltag/7/
# http://www.worldfootball.net/schedule/eng-premier-league-2000-2001-spieltag/8/
# http://www.worldfootball.net/schedule/eng-premier-league-2000-2001-spieltag/9/
# http://www.worldfootball.net/schedule/eng-premier-league-2000-2001-spieltag/10/
# http://www.worldfootball.net/schedule/eng-premier-league-2000-2001-spieltag/11/
# http://www.worldfootball.net/schedule/eng-premier-league-2000-2001-spieltag/12/
# ...

# %%
# coding: utf-8
import re
import os
import csv
import time
import requests
import random

from bs4 import BeautifulSoup as BS

find = re.compile(r"^(:*?)\..*")

yearlist=["2000-2001","2001-2002","2002-2003","2003-2004","2004-2005","2005-2006","2006-2007","2007-2008","2008-2009","2009-2010","2010-2011","2011-2012","2012-2013","2013-2014","2014-2015","2015-2016","2016-2017"]
roundlist=["1-runde","2-runde","3-runde","4-runde","achtelfinale","viertelfinale","halbfinale","finale"]

for year in yearlist:
    newpath = "Football/"+year+"/" 
    if not os.path.exists(newpath):
        os.makedirs(newpath)
    with open((newpath+'saveFA_{}.csv').format(year), 'w') as resultsfile:

        resultsfileWriter = csv.writer(resultsfile)
        firstrow=("kickoffdate","kickofftime","hometeam","hometeamgoals","awayteam","awayteamgoals")
        resultsfileWriter.writerow(firstrow)

        for roundname in roundlist:
            daynumber=daynumber+1
            link="http://www.worldfootball.net/schedule/eng-fa-cup-{}-{}/0/".format(year,roundname)
            print(link)
            footie_page = requests.get(link).text
            soup = BS(footie_page, 'html.parser')
            soccer_table = soup.find('table', class_='standard_tabelle')
            #print(soccer_table)
            rows = soccer_table.find_all('tr')
            for row in rows:
                date = row.find_all('td', {"align": "center", "nowrap":"nowrap"})
                try:
                    if(date[0].text)!="":
                        kickoffdate=(date[0].text)
                    kickofftime=(date[1].text)
                    #print(kickoffdate+" "+kickofftime)
                    hometeam = row.find_all('td')[2].text.replace('\n','')
                    awayteam = row.find_all('td')[4].text.replace('\n','')
                    #print(hometeam+"vs"+awayteam)
                    result = row.find_all('td')[5].text
                    #print(result)
                    character=""
                    hometeamgoals=""
                    awayteamgoals=""
                    i=-1
                    while(character!=":"):
                        hometeamgoals+=character
                        i+=1
                        character=str(result[i])
                    i+=1
                    character=str(result[i])
                    while(character!=" "):
                        awayteamgoals+=character
                        i+=1
                        character=str(result[i])
                except IndexError:
                    kickoffdate=""
                    kickofftime=""
                    hometeam=""
                    hometeamgoals=""
                    awayteam=""
                    awayteamgoals=""
                #print(hometeamgoals)
                #print(awayteamgoals)
                output_list=(kickoffdate,kickofftime,hometeam,hometeamgoals,awayteam,awayteamgoals)
                resultsfileWriter.writerow(output_list)
# Out:
# http://www.worldfootball.net/schedule/eng-fa-cup-2000-2001-1-runde/0/
# http://www.worldfootball.net/schedule/eng-fa-cup-2000-2001-2-runde/0/
# http://www.worldfootball.net/schedule/eng-fa-cup-2000-2001-3-runde/0/
# http://www.worldfootball.net/schedule/eng-fa-cup-2000-2001-4-runde/0/
# http://www.worldfootball.net/schedule/eng-fa-cup-2000-2001-achtelfinale/0/
# http://www.worldfootball.net/schedule/eng-fa-cup-2000-2001-viertelfinale/0/
# http://www.worldfootball.net/schedule/eng-fa-cup-2000-2001-halbfinale/0/
# http://www.worldfootball.net/schedule/eng-fa-cup-2000-2001-finale/0/
# http://www.worldfootball.net/schedule/eng-fa-cup-2001-2002-1-runde/0/
# http://www.worldfootball.net/schedule/eng-fa-cup-2001-2002-2-runde/0/
# http://www.worldfootball.net/schedule/eng-fa-cup-2001-2002-3-runde/0/
# http://www.worldfootball.net/schedule/eng-fa-cup-2001-2002-4-runde/0/
# http://www.worldfootball.net/schedule/eng-fa-cup-2001-2002-achtelfinale/0/
# ...

# %%
# coding: utf-8
import re
import os
import csv
import time
import requests
import random

from bs4 import BeautifulSoup as BS

find = re.compile(r"^(:*?)\..*")

yearlist=["2000-2001","2001-2002","2002-2003","2003-2004","2004-2005","2005-2006","2006-2007","2007-2008","2008-2009","2009-2010","2010-2011","2011-2012","2012-2013","2013-2014","2014-2015","2015-2016","2016-2017"]
roundlist=["1-runde","2-runde","3-runde","achtelfinale","viertelfinale","halbfinale","finale"]
for year in yearlist:
    newpath = "Football/"+year+"/" 
    if not os.path.exists(newpath):
        os.makedirs(newpath)
    with open((newpath+'saveLeagueCoup_Round_{}.csv').format(year), 'w') as resultsfile:

        resultsfileWriter = csv.writer(resultsfile)
        firstrow=("kickoffdate","kickofftime","hometeam","hometeamgoals","awayteam","awayteamgoals")
        resultsfileWriter.writerow(firstrow)

        for roundname in roundlist:
                daynumber=daynumber+1
                link="http://www.worldfootball.net/schedule/eng-league-cup-{}-{}/0/".format(year,roundname)
                print(link)
                try:
                    footie_page = requests.get(link).text
                    soup = BS(footie_page, 'html.parser')
                    soccer_table = soup.find('table', class_='standard_tabelle')
                    #print(soccer_table)
                    rows = soccer_table.find_all('tr')
                except AttributeError:
                    print("result missing")
                for row in rows:
                    date = row.find_all('td', {"align": "center", "nowrap":"nowrap"})
                    try:
                        if(date[0].text)!="":
                            kickoffdate=(date[0].text)
                        kickofftime=(date[1].text)
                        #print(kickoffdate+" "+kickofftime)
                        hometeam = row.find_all('td')[2].text.replace('\n','')
                        awayteam = row.find_all('td')[4].text.replace('\n','')
                        #print(hometeam+"vs"+awayteam)
                        result = row.find_all('td')[5].text
                        #print(result)
                        character=""
                        hometeamgoals=""
                        awayteamgoals=""
                        i=-1
                        while(character!=":"):
                            hometeamgoals+=character
                            i+=1
                            character=str(result[i])
                        i+=1
                        character=str(result[i])
                        while(character!=" "):
                            awayteamgoals+=character
                            i+=1
                            character=str(result[i])
                    except IndexError:
                        kickoffdate=""
                        kickofftime=""
                        hometeam=""
                        hometeamgoals=""
                        awayteam=""
                        awayteamgoals=""
                    #print(hometeamgoals)
                    #print(awayteamgoals)
                    output_list=(kickoffdate,kickofftime,hometeam,hometeamgoals,awayteam,awayteamgoals)
                    resultsfileWriter.writerow(output_list)
# Out:
# http://www.worldfootball.net/schedule/eng-league-cup-2000-2001-1-runde/0/
# http://www.worldfootball.net/schedule/eng-league-cup-2000-2001-2-runde/0/
# http://www.worldfootball.net/schedule/eng-league-cup-2000-2001-3-runde/0/
# http://www.worldfootball.net/schedule/eng-league-cup-2000-2001-achtelfinale/0/
# http://www.worldfootball.net/schedule/eng-league-cup-2000-2001-viertelfinale/0/
# http://www.worldfootball.net/schedule/eng-league-cup-2000-2001-halbfinale/0/
# http://www.worldfootball.net/schedule/eng-league-cup-2000-2001-finale/0/
# http://www.worldfootball.net/schedule/eng-league-cup-2001-2002-1-runde/0/
# http://www.worldfootball.net/schedule/eng-league-cup-2001-2002-2-runde/0/
# http://www.worldfootball.net/schedule/eng-league-cup-2001-2002-3-runde/0/
# http://www.worldfootball.net/schedule/eng-league-cup-2001-2002-achtelfinale/0/
# http://www.worldfootball.net/schedule/eng-league-cup-2001-2002-viertelfinale/0/
# ...

# %%
# coding: utf-8
import re
import os
import csv
import time
import requests
import random

from bs4 import BeautifulSoup as BS

find = re.compile(r"^(:*?)\..*")

yearlist=["2000-2001","2001-2002","2002-2003","2003-2004","2004-2005","2005-2006","2006-2007","2007-2008","2008-2009","2009-2010","2010-2011","2011-2012","2012-2013","2013-2014","2014-2015","2015-2016","2016-2017"]
kolist=["achtelfinale","viertelfinale","halbfinale"]


for year in yearlist:
    newpath = "Football/"+year+"/" 
    if not os.path.exists(newpath):
        os.makedirs(newpath)
    with open((newpath+'saveCL_ko_{}.csv').format(year), 'w') as resultsfile:

        resultsfileWriter = csv.writer(resultsfile)
        firstrow=("kickoffdate","kickofftime","hometeam","hometeamgoals","awayteam","awayteamgoals")
        resultsfileWriter.writerow(firstrow)

        for roundname in kolist:
                daynumber=daynumber+1
                link="http://www.worldfootball.net/schedule/champions-league-{}-{}/0/".format(year,roundname)
                print(link)
                footie_page = requests.get(link).text
                soup = BS(footie_page, 'html.parser')
                soccer_table = soup.find('table', class_='standard_tabelle')
                #print(soccer_table)
                rows = soccer_table.find_all('tr')
                TRcounter=0
                for row in rows:
                    TRcounter+=1
                    #print(TRcounter)
                    date = row.find_all('td')
                    try:
                        if TRcounter==1:
                            hometeam1 = row.find_all('td')[1].text.replace('\n','')
                            awayteam1 = row.find_all('td')[3].text.replace('\n','')
                            result1 = row.find_all('td')[4].text
                            character=""
                            hometeamgoals1=""
                            awayteamgoals1=""
                            i=-1
                            while(character!=":"):
                                hometeamgoals1+=character
                                i+=1
                                character=str(result1[i])
                            i+=1
                            character=str(result1[i])
                            while(character!=" "):
                                awayteamgoals1+=character
                                i+=1
                                character=str(result1[i])

                        if TRcounter==2:
                            hometeam2 = row.find_all('td')[1].text.replace('\n','')
                            awayteam2 = row.find_all('td')[3].text.replace('\n','')
                            result2 = row.find_all('td')[4].text
                            character=""
                            hometeamgoals2=""
                            awayteamgoals2=""
                            i=-1
                            while(character!=":"):
                                hometeamgoals2+=character
                                i+=1
                                character=str(result2[i])
                            i+=1
                            character=str(result2[i])
                            while(character!=" "):
                                awayteamgoals2+=character
                                i+=1
                                character=str(result2[i])
                        if TRcounter==3:
                            date1 = row.find_all('td')[1].text
                            date2 = row.find_all('td')[3].text
                            dateday1 = date1[14:24]
                            datedtime1 = date1[25:30]
                            dateday2 = date2[15:25]
                            datedtime2 = date2[26:31]
                            #print(dateday1)
                        if TRcounter==4:
                            output_list1=(dateday1,datedtime1,hometeam1,hometeamgoals1,awayteam1,awayteamgoals1)
                            resultsfileWriter.writerow(output_list1)
                            output_list2=(dateday2,datedtime2,hometeam2,hometeamgoals2,awayteam2,awayteamgoals2)
                            resultsfileWriter.writerow(output_list2)
                            TRcounter=0
                    except IndexError:
                        output_list1=(0,0,0,0,0,0)
                        resultsfileWriter.writerow(output_list1)
                        output_list2=(0,0,0,0,0,0)
                        resultsfileWriter.writerow(output_list2)
                    #print(hometeamgoals)
                    #print(awayteamgoals)
                    #resultsfileWriter.writerow(output_list)
# Out:
# http://www.worldfootball.net/schedule/champions-league-2000-2001-achtelfinale/0/
# http://www.worldfootball.net/schedule/champions-league-2000-2001-viertelfinale/0/
# http://www.worldfootball.net/schedule/champions-league-2000-2001-halbfinale/0/
# http://www.worldfootball.net/schedule/champions-league-2001-2002-achtelfinale/0/
# http://www.worldfootball.net/schedule/champions-league-2001-2002-viertelfinale/0/
# http://www.worldfootball.net/schedule/champions-league-2001-2002-halbfinale/0/
# http://www.worldfootball.net/schedule/champions-league-2002-2003-achtelfinale/0/
# http://www.worldfootball.net/schedule/champions-league-2002-2003-viertelfinale/0/
# http://www.worldfootball.net/schedule/champions-league-2002-2003-halbfinale/0/
# http://www.worldfootball.net/schedule/champions-league-2003-2004-achtelfinale/0/
# http://www.worldfootball.net/schedule/champions-league-2003-2004-viertelfinale/0/
# http://www.worldfootball.net/schedule/champions-league-2003-2004-halbfinale/0/
# ...

# %%
# coding: utf-8
import re
import os
import csv
import time
import requests
import random

from bs4 import BeautifulSoup as BS

find = re.compile(r"^(:*?)\..*")

yearlist=["2000-2001","2001-2002","2002-2003","2003-2004","2004-2005","2005-2006","2006-2007","2007-2008","2008-2009","2009-2010","2010-2011","2011-2012","2012-2013","2013-2014","2014-2015","2015-2016","2016-2017"]
roundlist=["gruppe-a","gruppe-b","gruppe-c","gruppe-d","gruppe-e","gruppe-f","gruppe-g","gruppe-h","finale"]
for year in yearlist:
    newpath = "Football/"+year+"/" 
    if not os.path.exists(newpath):
        os.makedirs(newpath)
    with open((newpath+'saveCL_Group_{}.csv').format(year), 'w') as resultsfile:

        resultsfileWriter = csv.writer(resultsfile)
        firstrow=("kickoffdate","kickofftime","hometeam","hometeamgoals","awayteam","awayteamgoals")
        resultsfileWriter.writerow(firstrow)

        for roundname in roundlist:
                daynumber=daynumber+1
                link="http://www.worldfootball.net/schedule/champions-league-{}-{}/0/".format(year,roundname)
                print(link)
                footie_page = requests.get(link).text
                soup = BS(footie_page, 'html.parser')
                soccer_table = soup.find('table', class_='standard_tabelle')
                #print(soccer_table)
                rows = soccer_table.find_all('tr')
                for row in rows:
                    date = row.find_all('td', {"align": "center", "nowrap":"nowrap"})
                    try:
                        if(date[0].text)!="":
                            kickoffdate=(date[0].text)
                        kickofftime=(date[1].text)
                        #print(kickoffdate+" "+kickofftime)
                        hometeam = row.find_all('td')[2].text.replace('\n','')
                        awayteam = row.find_all('td')[4].text.replace('\n','')
                        #print(hometeam+"vs"+awayteam)
                        result = row.find_all('td')[5].text
                        #print(result)
                        character=""
                        hometeamgoals=""
                        awayteamgoals=""
                        i=-1
                        while(character!=":"):
                            hometeamgoals+=character
                            i+=1
                            character=str(result[i])
                        i+=1
                        character=str(result[i])
                        while(character!=" "):
                            awayteamgoals+=character
                            i+=1
                            character=str(result[i])
                    except IndexError:
                        kickoffdate=""
                        kickofftime=""
                        hometeam=""
                        hometeamgoals=""
                        awayteam=""
                        awayteamgoals=""
                    #print(hometeamgoals)
                    #print(awayteamgoals)
                    output_list=(kickoffdate,kickofftime,hometeam,hometeamgoals,awayteam,awayteamgoals)
                    resultsfileWriter.writerow(output_list)
# Out:
# http://www.worldfootball.net/schedule/champions-league-2000-2001-gruppe-a/0/
# http://www.worldfootball.net/schedule/champions-league-2000-2001-gruppe-b/0/
# http://www.worldfootball.net/schedule/champions-league-2000-2001-gruppe-c/0/
# http://www.worldfootball.net/schedule/champions-league-2000-2001-gruppe-d/0/
# http://www.worldfootball.net/schedule/champions-league-2000-2001-gruppe-e/0/
# http://www.worldfootball.net/schedule/champions-league-2000-2001-gruppe-f/0/
# http://www.worldfootball.net/schedule/champions-league-2000-2001-gruppe-g/0/
# http://www.worldfootball.net/schedule/champions-league-2000-2001-gruppe-h/0/
# http://www.worldfootball.net/schedule/champions-league-2000-2001-finale/0/
# http://www.worldfootball.net/schedule/champions-league-2001-2002-gruppe-a/0/
# http://www.worldfootball.net/schedule/champions-league-2001-2002-gruppe-b/0/
# http://www.worldfootball.net/schedule/champions-league-2001-2002-gruppe-c/0/
# ...

# %%
# coding: utf-8
import re
import os
import csv
import time
import requests
import random

from bs4 import BeautifulSoup as BS

find = re.compile(r"^(:*?)\..*")

yearlist=["2000-2001","2001-2002","2002-2003","2003-2004","2004-2005","2005-2006","2006-2007","2007-2008","2008-2009","2009-2010","2010-2011","2011-2012","2012-2013","2013-2014","2014-2015","2015-2016","2016-2017"]
roundlist=["gruppe-a","gruppe-b","gruppe-c","gruppe-d","gruppe-e","gruppe-f","gruppe-g","gruppe-h","gruppe-i","gruppe-j","gruppe-k","gruppe-l","finale"]
for year in yearlist:
    newpath = "Football/"+year+"/" 
    if not os.path.exists(newpath):
        os.makedirs(newpath)
    with open((newpath+'saveEL_group_{}.csv').format(year), 'w') as resultsfile:

        resultsfileWriter = csv.writer(resultsfile)
        firstrow=("kickoffdate","kickofftime","hometeam","hometeamgoals","awayteam","awayteamgoals")
        resultsfileWriter.writerow(firstrow)

        for roundname in roundlist:
                daynumber=daynumber+1
                link="http://www.worldfootball.net/schedule/europa-league-{}-{}/0/".format(year,roundname)
                print(link)
                footie_page = requests.get(link).text
                soup = BS(footie_page, 'html.parser')
                soccer_table = soup.find('table', class_='standard_tabelle')
                #print(soccer_table)
                rows = soccer_table.find_all('tr')
                for row in rows:
                    date = row.find_all('td', {"align": "center", "nowrap":"nowrap"})
                    try:
                        if(date[0].text)!="":
                            kickoffdate=(date[0].text)
                        kickofftime=(date[1].text)
                        #print(kickoffdate+" "+kickofftime)
                        hometeam = row.find_all('td')[2].text.replace('\n','')
                        awayteam = row.find_all('td')[4].text.replace('\n','')
                        #print(hometeam+"vs"+awayteam)
                        result = row.find_all('td')[5].text
                        #print(result)
                        character=""
                        hometeamgoals=""
                        awayteamgoals=""
                        i=-1
                        while(character!=":"):
                            hometeamgoals+=character
                            i+=1
                            character=str(result[i])
                        i+=1
                        character=str(result[i])
                        while(character!=" "):
                            awayteamgoals+=character
                            i+=1
                            character=str(result[i])
                    except IndexError:
                        kickoffdate=""
                        kickofftime=""
                        hometeam=""
                        hometeamgoals=""
                        awayteam=""
                        awayteamgoals=""
                    #print(hometeamgoals)
                    #print(awayteamgoals)
                    output_list=(kickoffdate,kickofftime,hometeam,hometeamgoals,awayteam,awayteamgoals)
                    resultsfileWriter.writerow(output_list)
# Out:
# http://www.worldfootball.net/schedule/europa-league-2000-2001-gruppe-a/0/
# http://www.worldfootball.net/schedule/europa-league-2000-2001-gruppe-b/0/
# http://www.worldfootball.net/schedule/europa-league-2000-2001-gruppe-c/0/
# http://www.worldfootball.net/schedule/europa-league-2000-2001-gruppe-d/0/
# http://www.worldfootball.net/schedule/europa-league-2000-2001-gruppe-e/0/
# http://www.worldfootball.net/schedule/europa-league-2000-2001-gruppe-f/0/
# http://www.worldfootball.net/schedule/europa-league-2000-2001-gruppe-g/0/
# http://www.worldfootball.net/schedule/europa-league-2000-2001-gruppe-h/0/
# http://www.worldfootball.net/schedule/europa-league-2000-2001-gruppe-i/0/
# http://www.worldfootball.net/schedule/europa-league-2000-2001-gruppe-j/0/
# http://www.worldfootball.net/schedule/europa-league-2000-2001-gruppe-k/0/
# http://www.worldfootball.net/schedule/europa-league-2000-2001-gruppe-l/0/
# http://www.worldfootball.net/schedule/europa-league-2000-2001-finale/0/
# ...

# %%
# coding: utf-8
import re
import os
import csv
import time
import requests
import random

from bs4 import BeautifulSoup as BS

find = re.compile(r"^(:*?)\..*")

yearlist=["2000-2001","2001-2002","2002-2003","2003-2004","2004-2005","2005-2006","2006-2007","2007-2008","2008-2009","2009-2010","2010-2011","2011-2012","2012-2013","2013-2014","2014-2015","2015-2016","2016-2017"]
kolist=["sechzehntelfinale","achtelfinale","viertelfinale","halbfinale"]


for year in yearlist:
    newpath = "Football/"+year+"/" 
    if not os.path.exists(newpath):
        os.makedirs(newpath)
    with open((newpath+'saveEL_ko_{}.csv').format(year), 'w') as resultsfile:

        resultsfileWriter = csv.writer(resultsfile)
        firstrow=("kickoffdate","kickofftime","hometeam","hometeamgoals","awayteam","awayteamgoals")
        resultsfileWriter.writerow(firstrow)

        for roundname in kolist:
                daynumber=daynumber+1
                link="http://www.worldfootball.net/schedule/europa-league-{}-{}/0/".format(year,roundname)
                print(link)
                footie_page = requests.get(link).text
                soup = BS(footie_page, 'html.parser')
                soccer_table = soup.find('table', class_='standard_tabelle')
                #print(soccer_table)
                rows = soccer_table.find_all('tr')
                TRcounter=0
                for row in rows:
                    TRcounter+=1
                    #print(TRcounter)
                    date = row.find_all('td')
                    try:
                        if TRcounter==1:
                            hometeam1 = row.find_all('td')[1].text.replace('\n','')
                            awayteam1 = row.find_all('td')[3].text.replace('\n','')
                            result1 = row.find_all('td')[4].text
                            character=""
                            hometeamgoals1=""
                            awayteamgoals1=""
                            i=-1
                            while(character!=":"):
                                hometeamgoals1+=character
                                i+=1
                                character=str(result1[i])
                            i+=1
                            character=str(result1[i])
                            while(character!=" "):
                                awayteamgoals1+=character
                                i+=1
                                character=str(result1[i])

                        if TRcounter==2:
                            hometeam2 = row.find_all('td')[1].text.replace('\n','')
                            awayteam2 = row.find_all('td')[3].text.replace('\n','')
                            result2 = row.find_all('td')[4].text
                            character=""
                            hometeamgoals2=""
                            awayteamgoals2=""
                            i=-1
                            while(character!=":"):
                                hometeamgoals2+=character
                                i+=1
                                character=str(result2[i])
                            i+=1
                            character=str(result2[i])
                            while(character!=" "):
                                awayteamgoals2+=character
                                i+=1
                                character=str(result2[i])
                        if TRcounter==3:
                            date1 = row.find_all('td')[1].text
                            date2 = row.find_all('td')[3].text
                            dateday1 = date1[14:24]
                            datedtime1 = date1[25:30]
                            dateday2 = date2[15:25]
                            datedtime2 = date2[26:31]
                            #print(dateday1)
                        if TRcounter==4:
                            output_list1=(dateday1,datedtime1,hometeam1,hometeamgoals1,awayteam1,awayteamgoals1)
                            resultsfileWriter.writerow(output_list1)
                            output_list2=(dateday2,datedtime2,hometeam2,hometeamgoals2,awayteam2,awayteamgoals2)
                            resultsfileWriter.writerow(output_list2)
                            TRcounter=0
                    except IndexError:
                        output_list1=(0,0,0,0,0,0)
                        resultsfileWriter.writerow(output_list1)
                        output_list2=(0,0,0,0,0,0)
                        resultsfileWriter.writerow(output_list2)
                    #print(hometeamgoals)
                    #print(awayteamgoals)
                    #resultsfileWriter.writerow(output_list)
# Out:
# http://www.worldfootball.net/schedule/europa-league-2000-2001-sechzehntelfinale/0/
# http://www.worldfootball.net/schedule/europa-league-2000-2001-achtelfinale/0/
# http://www.worldfootball.net/schedule/europa-league-2000-2001-viertelfinale/0/
# http://www.worldfootball.net/schedule/europa-league-2000-2001-halbfinale/0/
# http://www.worldfootball.net/schedule/europa-league-2001-2002-sechzehntelfinale/0/
# http://www.worldfootball.net/schedule/europa-league-2001-2002-achtelfinale/0/
# http://www.worldfootball.net/schedule/europa-league-2001-2002-viertelfinale/0/
# http://www.worldfootball.net/schedule/europa-league-2001-2002-halbfinale/0/
# http://www.worldfootball.net/schedule/europa-league-2002-2003-sechzehntelfinale/0/
# http://www.worldfootball.net/schedule/europa-league-2002-2003-achtelfinale/0/
# http://www.worldfootball.net/schedule/europa-league-2002-2003-viertelfinale/0/
# http://www.worldfootball.net/schedule/europa-league-2002-2003-halbfinale/0/
# ...

# %%
# coding: utf-8
import re
import os
import csv
import time
import requests
import random

from bs4 import BeautifulSoup as BS

find = re.compile(r"^(:*?)\..*")

yearlist=["2000-2001","2001-2002","2002-2003","2003-2004","2004-2005","2005-2006","2006-2007","2007-2008","2008-2009","2009-2010","2010-2011","2011-2012","2012-2013","2013-2014","2014-2015","2015-2016","2016-2017"]
roundlist=["1-runde","2-runde","3-runde","playoffs"]
for year in yearlist:
    newpath = "Football/"+year+"/" 
    if not os.path.exists(newpath):
        os.makedirs(newpath)
    with open((newpath+'saveEL_Qual_{}.csv').format(year), 'w') as resultsfile:

        resultsfileWriter = csv.writer(resultsfile)
        firstrow=("kickoffdate","kickofftime","hometeam","hometeamgoals","awayteam","awayteamgoals")
        resultsfileWriter.writerow(firstrow)

        for roundname in roundlist:
                daynumber=daynumber+1
                link="http://www.worldfootball.net/schedule/europa-league-qual-{}-{}/0/".format(year,roundname)
                print(link)
                footie_page = requests.get(link).text
                soup = BS(footie_page, 'html.parser')
                soccer_table = soup.find('table', class_='standard_tabelle')
                #print(soccer_table)
                rows = soccer_table.find_all('tr')
                TRcounter=0
                for row in rows:
                    TRcounter+=1
                    #print(TRcounter)
                    date = row.find_all('td')
                    try:
                        if TRcounter==1:
                            hometeam1 = row.find_all('td')[1].text.replace('\n','')
                            awayteam1 = row.find_all('td')[3].text.replace('\n','')
                            result1 = row.find_all('td')[4].text
                            character=""
                            hometeamgoals1=""
                            awayteamgoals1=""
                            i=-1
                            while(character!=":"):
                                hometeamgoals1+=character
                                i+=1
                                character=str(result1[i])
                            i+=1
                            character=str(result1[i])
                            while(character!=" "):
                                awayteamgoals1+=character
                                i+=1
                                character=str(result1[i])

                        if TRcounter==2:
                            hometeam2 = row.find_all('td')[1].text.replace('\n','')
                            awayteam2 = row.find_all('td')[3].text.replace('\n','')
                            result2 = row.find_all('td')[4].text
                            character=""
                            hometeamgoals2=""
                            awayteamgoals2=""
                            i=-1
                            while(character!=":"):
                                hometeamgoals2+=character
                                i+=1
                                character=str(result2[i])
                            i+=1
                            character=str(result2[i])
                            while(character!=" "):
                                awayteamgoals2+=character
                                i+=1
                                character=str(result2[i])
                        if TRcounter==3:
                            date1 = row.find_all('td')[1].text
                            date2 = row.find_all('td')[3].text
                            dateday1 = date1[14:24]
                            datedtime1 = date1[25:30]
                            dateday2 = date2[15:25]
                            datedtime2 = date2[26:31]
                            #print(dateday1)
                        if TRcounter==4:
                            output_list1=(dateday1,datedtime1,hometeam1,hometeamgoals1,awayteam1,awayteamgoals1)
                            resultsfileWriter.writerow(output_list1)
                            output_list2=(dateday2,datedtime2,hometeam2,hometeamgoals2,awayteam2,awayteamgoals2)
                            resultsfileWriter.writerow(output_list2)
                            TRcounter=0
                    except IndexError:
                        output_list1=(0,0,0,0,0,0)
                        resultsfileWriter.writerow(output_list1)
                        output_list2=(0,0,0,0,0,0)
                        resultsfileWriter.writerow(output_list2)
                    #print(hometeamgoals)
                    #print(awayteamgoals)
                    #resultsfileWriter.writerow(output_list)
# Out:
# http://www.worldfootball.net/schedule/europa-league-qual-2000-2001-1-runde/0/
# http://www.worldfootball.net/schedule/europa-league-qual-2000-2001-2-runde/0/
# http://www.worldfootball.net/schedule/europa-league-qual-2000-2001-3-runde/0/
# http://www.worldfootball.net/schedule/europa-league-qual-2000-2001-playoffs/0/
# http://www.worldfootball.net/schedule/europa-league-qual-2001-2002-1-runde/0/
# http://www.worldfootball.net/schedule/europa-league-qual-2001-2002-2-runde/0/
# http://www.worldfootball.net/schedule/europa-league-qual-2001-2002-3-runde/0/
# http://www.worldfootball.net/schedule/europa-league-qual-2001-2002-playoffs/0/
# http://www.worldfootball.net/schedule/europa-league-qual-2002-2003-1-runde/0/
# http://www.worldfootball.net/schedule/europa-league-qual-2002-2003-2-runde/0/
# http://www.worldfootball.net/schedule/europa-league-qual-2002-2003-3-runde/0/
# http://www.worldfootball.net/schedule/europa-league-qual-2002-2003-playoffs/0/
# ...

# %%
# coding: utf-8
import re
import os
import csv
import time
import requests
import random

from bs4 import BeautifulSoup as BS

find = re.compile(r"^(:*?)\..*")

yearlist=["2000-2001","2001-2002","2002-2003","2003-2004","2004-2005","2005-2006","2006-2007","2007-2008","2008-2009","2009-2010","2010-2011","2011-2012","2012-2013","2013-2014","2014-2015","2015-2016","2016-2017"]
roundlist=["1-runde","2-runde","3-runde","playoffs"]
for year in yearlist:
    newpath = "Football/"+year+"/" 
    if not os.path.exists(newpath):
        os.makedirs(newpath)
    with open((newpath+'saveCL_Qual_{}.csv').format(year), 'w') as resultsfile:

        resultsfileWriter = csv.writer(resultsfile)
        firstrow=("kickoffdate","kickofftime","hometeam","hometeamgoals","awayteam","awayteamgoals")
        resultsfileWriter.writerow(firstrow)

        for roundname in roundlist:
                daynumber=daynumber+1
                link="http://www.worldfootball.net/schedule/champions-league-qual-{}-{}/0/".format(year,roundname)
                print(link)
                footie_page = requests.get(link).text
                soup = BS(footie_page, 'html.parser')
                soccer_table = soup.find('table', class_='standard_tabelle')
                #print(soccer_table)
                rows = soccer_table.find_all('tr')
                TRcounter=0
                for row in rows:
                    TRcounter+=1
                    #print(TRcounter)
                    date = row.find_all('td')
                    try:
                        if TRcounter==1:
                            hometeam1 = row.find_all('td')[1].text.replace('\n','')
                            awayteam1 = row.find_all('td')[3].text.replace('\n','')
                            result1 = row.find_all('td')[4].text
                            character=""
                            hometeamgoals1=""
                            awayteamgoals1=""
                            i=-1
                            while(character!=":"):
                                hometeamgoals1+=character
                                i+=1
                                character=str(result1[i])
                            i+=1
                            character=str(result1[i])
                            while(character!=" "):
                                awayteamgoals1+=character
                                i+=1
                                character=str(result1[i])

                        if TRcounter==2:
                            hometeam2 = row.find_all('td')[1].text.replace('\n','')
                            awayteam2 = row.find_all('td')[3].text.replace('\n','')
                            result2 = row.find_all('td')[4].text
                            character=""
                            hometeamgoals2=""
                            awayteamgoals2=""
                            i=-1
                            while(character!=":"):
                                hometeamgoals2+=character
                                i+=1
                                character=str(result2[i])
                            i+=1
                            character=str(result2[i])
                            while(character!=" "):
                                awayteamgoals2+=character
                                i+=1
                                character=str(result2[i])
                        if TRcounter==3:
                            date1 = row.find_all('td')[1].text
                            date2 = row.find_all('td')[3].text
                            dateday1 = date1[14:24]
                            datedtime1 = date1[25:30]
                            dateday2 = date2[15:25]
                            datedtime2 = date2[26:31]
                            #print(dateday1)
                        if TRcounter==4:
                            output_list1=(dateday1,datedtime1,hometeam1,hometeamgoals1,awayteam1,awayteamgoals1)
                            resultsfileWriter.writerow(output_list1)
                            output_list2=(dateday2,datedtime2,hometeam2,hometeamgoals2,awayteam2,awayteamgoals2)
                            resultsfileWriter.writerow(output_list2)
                            TRcounter=0
                    except IndexError:
                        output_list1=(0,0,0,0,0,0)
                        resultsfileWriter.writerow(output_list1)
                        output_list2=(0,0,0,0,0,0)
                        resultsfileWriter.writerow(output_list2)
                    #print(hometeamgoals)
                    #print(awayteamgoals)
                    #resultsfileWriter.writerow(output_list)
# Out:
# http://www.worldfootball.net/schedule/champions-league-qual-2000-2001-1-runde/0/
# http://www.worldfootball.net/schedule/champions-league-qual-2000-2001-2-runde/0/
# http://www.worldfootball.net/schedule/champions-league-qual-2000-2001-3-runde/0/
# http://www.worldfootball.net/schedule/champions-league-qual-2000-2001-playoffs/0/
# http://www.worldfootball.net/schedule/champions-league-qual-2001-2002-1-runde/0/
# http://www.worldfootball.net/schedule/champions-league-qual-2001-2002-2-runde/0/
# http://www.worldfootball.net/schedule/champions-league-qual-2001-2002-3-runde/0/
# http://www.worldfootball.net/schedule/champions-league-qual-2001-2002-playoffs/0/
# http://www.worldfootball.net/schedule/champions-league-qual-2002-2003-1-runde/0/
# http://www.worldfootball.net/schedule/champions-league-qual-2002-2003-2-runde/0/
# http://www.worldfootball.net/schedule/champions-league-qual-2002-2003-3-runde/0/
# http://www.worldfootball.net/schedule/champions-league-qual-2002-2003-playoffs/0/
# ...

# %%
# coding: utf-8
import re
import os
import csv
import time
import requests
import random

from bs4 import BeautifulSoup as BS

find = re.compile(r"^(:*?)\..*")

yearlist=["2000-2001","2001-2002","2002-2003","2003-2004","2004-2005","2005-2006","2006-2007","2007-2008","2008-2009"]
roundlist=["1-runde","2-runde","3-runde","4-runde","5-runde","halbfinale", "endspiel"]
for year in yearlist:
    newpath = "Football/"+year+"/" 
    if not os.path.exists(newpath):
        os.makedirs(newpath)
    with open((newpath+'saveUI_cup_{}.csv').format(year), 'w') as resultsfile:

        resultsfileWriter = csv.writer(resultsfile)
        firstrow=("kickoffdate","kickofftime","hometeam","hometeamgoals","awayteam","awayteamgoals")
        resultsfileWriter.writerow(firstrow)

        for roundname in roundlist:
                #daynumber=daynumber+1
                link="http://www.worldfootball.net/schedule/ui-cup-{}-{}/0/".format(year,roundname)
                print(link)
                footie_page = requests.get(link).text
                soup = BS(footie_page, 'html.parser')
                soccer_table = soup.find('table', class_='standard_tabelle')
                #print(soccer_table)
                rows = soccer_table.find_all('tr')
                TRcounter=0
                for row in rows:
                    TRcounter+=1
                    #print(TRcounter)
                    date = row.find_all('td')
                    try:
                        if TRcounter==1:
                            hometeam1 = row.find_all('td')[1].text.replace('\n','')
                            awayteam1 = row.find_all('td')[3].text.replace('\n','')
                            result1 = row.find_all('td')[4].text
                            character=""
                            hometeamgoals1=""
                            awayteamgoals1=""
                            i=-1
                            while(character!=":"):
                                hometeamgoals1+=character
                                i+=1
                                character=str(result1[i])
                            i+=1
                            character=str(result1[i])
                            while(character!=" "):
                                awayteamgoals1+=character
                                i+=1
                                character=str(result1[i])

                        if TRcounter==2:
                            hometeam2 = row.find_all('td')[1].text.replace('\n','')
                            awayteam2 = row.find_all('td')[3].text.replace('\n','')
                            result2 = row.find_all('td')[4].text
                            character=""
                            hometeamgoals2=""
                            awayteamgoals2=""
                            i=-1
                            while(character!=":"):
                                hometeamgoals2+=character
                                i+=1
                                character=str(result2[i])
                            i+=1
                            character=str(result2[i])
                            while(character!=" "):
                                awayteamgoals2+=character
                                i+=1
                                character=str(result2[i])
                        if TRcounter==3:
                            date1 = row.find_all('td')[1].text
                            date2 = row.find_all('td')[3].text
                            dateday1 = date1[14:24]
                            datedtime1 = date1[25:30]
                            dateday2 = date2[15:25]
                            datedtime2 = date2[26:31]
                            #print(dateday1)
                        if TRcounter==4:
                            output_list1=(dateday1,datedtime1,hometeam1,hometeamgoals1,awayteam1,awayteamgoals1)
                            resultsfileWriter.writerow(output_list1)
                            output_list2=(dateday2,datedtime2,hometeam2,hometeamgoals2,awayteam2,awayteamgoals2)
                            resultsfileWriter.writerow(output_list2)
                            TRcounter=0
                    except IndexError:
                        output_list1=(0,0,0,0,0,0)
                        resultsfileWriter.writerow(output_list1)
                        output_list2=(0,0,0,0,0,0)
                        resultsfileWriter.writerow(output_list2)
                    #print(hometeamgoals)
                    #print(awayteamgoals)
                    #resultsfileWriter.writerow(output_list)
# Out:
# http://www.worldfootball.net/schedule/ui-cup-2000-2001-1-runde/0/
# http://www.worldfootball.net/schedule/ui-cup-2000-2001-2-runde/0/
# http://www.worldfootball.net/schedule/ui-cup-2000-2001-3-runde/0/
# http://www.worldfootball.net/schedule/ui-cup-2000-2001-4-runde/0/
# http://www.worldfootball.net/schedule/ui-cup-2000-2001-5-runde/0/
# http://www.worldfootball.net/schedule/ui-cup-2000-2001-halbfinale/0/
# http://www.worldfootball.net/schedule/ui-cup-2000-2001-endspiel/0/
# http://www.worldfootball.net/schedule/ui-cup-2001-2002-1-runde/0/
# http://www.worldfootball.net/schedule/ui-cup-2001-2002-2-runde/0/
# http://www.worldfootball.net/schedule/ui-cup-2001-2002-3-runde/0/
# http://www.worldfootball.net/schedule/ui-cup-2001-2002-4-runde/0/
# http://www.worldfootball.net/schedule/ui-cup-2001-2002-5-runde/0/
# http://www.worldfootball.net/schedule/ui-cup-2001-2002-halbfinale/0/
# http://www.worldfootball.net/schedule/ui-cup-2001-2002-endspiel/0/
# ...

# %%
import pandas as pd
yearlist=["2000-2001","2001-2002","2002-2003","2003-2004","2004-2005","2005-2006","2006-2007","2007-2008","2008-2009"]
for year in yearlist:
    newpath = "Football/"+year+"/" 
    cheatclean=pd.read_csv((newpath+"save_UI_cup_{}.csv").format(year))
    cheatclean = cheatclean[cheatclean.hometeam != "0"]
    cheatclean.to_csv(("saveUI_cup_{}.csv").format(year))
cheatclean.tail()
# Out:
#    kickoffdate kickofftime        hometeam  hometeamgoals        awayteam  \
# 73  26/07/2008       17:15     Aston Villa              1       Odense BK
# 74  20/07/2008       17:00   Panionios GSS              0      SSC Napoli
# 75  26/07/2008       20:00      SSC Napoli              1   Panionios GSS
# 76  20/07/2008       17:00       Sivasspor              0  Sporting Braga
# 77  26/07/2008       19:00  Sporting Braga              3       Sivasspor
#
#     awayteamgoals
# 73              0
# 74              1
# 75              0
# 76              2
# 77              0
