# %%
import pandas as pd
import altair as alt
from IPython.display import display
alt.renderers.enable('notebook')
print(alt.renderers.active)
# Out:
# notebook

# %%
data=pd.read_excel("../RawData/Subventionsdatenbank März 2019.xlsx")

# %%
data.columns
# Out:
# Index(['id', 'publish', 'archiv', 'kreditnr', 'kurznr', 'ag', 'sort_aufgabe',
#        'bzsub', 'subgrund', 'aule',
#        ...
#        'Spalte16323', 'Spalte16324', 'Spalte16325', 'Spalte16326',
#        'Spalte16327', 'Spalte16328', 'Spalte16329', 'Spalte16330',
#        'Spalte16331', 'Spalte16332'],
#       dtype='object', length=16384)

# %%
cols = [c for c in data.columns if ('Spalte' not in c)]
cols
# Out:
# ['id',
#  'publish',
#  'archiv',
#  'kreditnr',
#  'kurznr',
#  'ag',
#  'sort_aufgabe',
#  'bzsub',
#  'subgrund',
#  'aule',
#  'firstyear',
#  'zi',
#  'zif',
#  'enempf',
#  '1980',
#  '1985',
#  '1990',
#  '1995',
#  '2000',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  'summe_diff',
#  'diff_wert',
#  'verbuchung',
#  'afihilfe',
#  'aabgelt',
#  'apflicht',
#  'form',
#  'dep',
#  'amt',
#  'amt_nr',
#  'reserve1',
#  'reserve2',
#  'reserve3',
#  'reserve4',
#  'reserve5',
#  'jahr_aktuell',
#  'last_year']

# %%
data[cols]
# Out:
#         id publish archiv   kreditnr  kurznr  \
# 0      1.0       Y      N  A231.0100    1045
# 1      2.0       Y      N  A231.0101    1045
# 2      3.0       Y      N  A231.0102    1045
# 3      4.0       Y      N  A231.0103    1045
# 4      5.0       Y      N  A231.0104    1041
# 5      6.0       Y      N  A231.0106    1019
# 6      7.0       Y      N  A231.0107    1019
# 7      8.0       Y      N  A231.0108    1019
# 8      9.0       Y      N  A231.0109    1019
# 9     10.0       Y      N  A231.0112    1019
# 10    11.0       Y      N  A231.0113    1035
# 11    12.0       Y      N  A231.0115     570
# 12    13.0       Y      N  A231.0116    1029
# 13    14.0       Y      N  A231.0119    1010
# 14    15.0       Y      N  A231.0120    1010
# 15    16.0       Y      N  A231.0121    1010
# 16    17.0       Y      N  A231.0122    1010
# 17    18.0       Y      N  A231.0123    1010
# 18    19.0       Y      N  A231.0124    1010
# 19    20.0       Y      N  A231.0125    1010
# ...

# %%
data.groupby(by="ag").sum()
# Out:
#                                                      id  kurznr          1995  \
# ag
# Allgemeines Rechtswesen                             0.0    2060  0.000000e+00
# Beziehungen zum Ausland                          8417.0   56070  1.421979e+09
# Bildung und Forschung                            5548.0   40035  1.909612e+09
# Gesundheit                                        999.0   10459  2.315062e+07
# Institutionelle und finanzielle Voraussetzungen  1570.0   11239  1.096311e+07
# Kultur und Freizeit                              2553.0   35768  1.332151e+08
# Landesverteidigung                                 17.0    4170  2.022404e+07
# Landesverteidigung                                  5.0    1041  0.000000e+00
# Landwirtschaft und Ernaehrung                    1692.0   15875  7.549149e+08
# Ordnung und oeffentliche Sicherheit              1619.0   13102  1.333696e+08
# Soziale Wohlfahrt                                4191.0   30276  7.093296e+09
# ...

# %%
data_null=data[["ag",'1980','1985','1990','1995','2000',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009',
 '2010',
 '2011',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016',
 '2017',
 '2018',
 '2019',
 '2020']].fillna(0)

# %%
gruende=data["dep"].unique().tolist()
gruende
# Out:
# ['VBS', 'EJPD', 'EDI', 'EFD', 'WBF', 'UVEK', 'EDA', nan]

# %%
for i in gruende:
    subdata=data[data["dep"]==i]
    subdata=subdata[["dep",'1980','1985','1990','1995','2000',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009',
 '2010',
 '2011',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016',
 '2017',
 '2018',
 '2019',
 '2020']]
    subdata=subdata.fillna(0)
    array=subdata.groupby(by="dep").sum()
    trans_array=array.transpose()
    trans_array=trans_array.reset_index()
    trans_array=trans_array.rename(columns={"index":"Jahr"})
    chart=alt.Chart(trans_array).mark_bar().encode(
    x='Jahr:T',
    y=i,
)
    display(chart)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-1da5f0cc60af> in <module>
#      25     chart=alt.Chart(trans_array).mark_bar().encode(
#      26     x='Jahr:T',
# ---> 27     y=i,
#      28 )
#      29     display(chart)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/altair/vegalite/v3/api.py in encode(self, *args, **kwargs)
#    1416                     obj['condition'] = _wrap_in_channel_class(condition, prop)
#    1417             if obj is not None:
# -> 1418                 kwargs[prop] = _wrap_in_channel_class(obj, prop)
#    1419
#    1420         copy = self.copy(deep=True, ignore=['data'])
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/altair/vegalite/v3/api.py in _wrap_in_channel_class(obj, prop)
# ...

# %%
for i in gruende:
    subdata=data[data["dep"]==i]
    subdata=subdata[["dep",'1980','1985','1990','1995','2000',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009',
 '2010',
 '2011',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016',
 '2017',
 '2018',
 '2019',
 '2020']]
    subdata=subdata.fillna(0)
    array=subdata.groupby(by="dep").sum()
    trans_array=array.transpose()
    trans_array=trans_array.reset_index()
    trans_array=trans_array.rename(columns={"index":"Jahr"})
    chart=alt.Chart(trans_array).mark_bar().encode(
    x='Jahr:T',
    y=i,
)
    display(chart)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/altair/vegalite/v3/api.py in to_dict(self, *args, **kwargs)
#     357         copy = self.copy()
#     358         original_data = getattr(copy, 'data', Undefined)
# --> 359         copy.data = _prepare_data(original_data, context)
#     360
#     361         if original_data is not Undefined:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/altair/vegalite/v3/api.py in _prepare_data(data, context)
#      82     # convert dataframes to dict
#      83     if isinstance(data, pd.DataFrame):
# ---> 84         data = pipe(data, data_transformers.get())
#      85
#      86     # convert string input to a URLData
#
# ...

# %%
percdata=data[["dep",'1980','1985','1990','1995','2000',
 '2005',
 '2006',
 '2007',
 '2008',
 '2009',
 '2010',
 '2011',
 '2012',
 '2013',
 '2014',
 '2015',
 '2016',
 '2017',
 '2018',
 '2019',
 '2020']]
col=['1980','1985','1990','1995','2000','2005','2006','2007', '2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019', '2020']
print(type(col))
for i in col:
    print(i)
    
    percdata[i] = pd.to_numeric(percdata[i], errors='coerce').fillna(0)


percdata=percdata.groupby(by="dep").sum()

percdata
# Out:
# <class 'list'>
# 1980
# 1985
# 1990
# 1995
# 2000
# 2005
# 2006
# 2007
# 2008
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
#               1980          1985          1990          1995          2000  \
# dep
# EDA   3.961563e+08  7.236407e+08  8.687277e+08  1.140251e+09  1.221733e+09
# EDI   2.521316e+09  3.778634e+09  5.191871e+09  7.191763e+09  1.030654e+10
# EFD   2.399989e+07  3.050000e+07  7.499997e+07  1.179999e+08  1.188422e+08
# EJPD  5.015457e+07  5.995038e+07  1.101117e+08  1.403048e+08  1.219092e+09
# ...

# %%
display(chart)

# %%
import altair as alt
from vega_datasets import data

# for the notebook only (not for JupyterLab) run this command once per session
alt.renderers.enable('notebook')

iris = data.iris()

(alt.Chart(iris).mark_point().encode(
    x='petalLength',
    y='petalWidth',
    color='species'
))

# %%
iris
# Out:
#      petalLength  petalWidth  sepalLength  sepalWidth    species
# 0            1.4         0.2          5.1         3.5     setosa
# 1            1.4         0.2          4.9         3.0     setosa
# 2            1.3         0.2          4.7         3.2     setosa
# 3            1.5         0.2          4.6         3.1     setosa
# 4            1.4         0.2          5.0         3.6     setosa
# 5            1.7         0.4          5.4         3.9     setosa
# 6            1.4         0.3          4.6         3.4     setosa
# 7            1.5         0.2          5.0         3.4     setosa
# 8            1.4         0.2          4.4         2.9     setosa
# 9            1.5         0.1          4.9         3.1     setosa
# 10           1.5         0.2          5.4         3.7     setosa
# 11           1.6         0.2          4.8         3.4     setosa
# 12           1.4         0.1          4.8         3.0     setosa
# ...
